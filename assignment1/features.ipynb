# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignment1_colab/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n/assignment1_colab/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n/assignment1_colab/assignment1

# %% [markdown]
# # Image features exercise
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# We have seen that we can achieve reasonable performance on an image classification task by training a linear classifier on the pixels of the input image. In this exercise we will show that we can improve our classification performance by training linear classifiers not on raw pixels but on features that are computed from the raw pixels.
#
# All of your work for this exercise will be done in this notebook.

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load data
# Similar to previous exercises, we will load CIFAR-10 data from disk.

# %%
from cs231n.features import color_histogram_hsv, hog_feature

def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000):
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'

    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # Subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    
    return X_train, y_train, X_val, y_val, X_test, y_test

X_train, y_train, X_val, y_val, X_test, y_test = get_CIFAR10_data()

# %%
print(X_train.shape,
      X_val.shape,
      y_train.shape,
      y_val.shape)
# Out:
# (49000, 32, 32, 3) (1000, 32, 32, 3) (49000,) (1000,)

# %% [markdown]
# ## Extract Features
# For each image we will compute a Histogram of Oriented
# Gradients (HOG) as well as a color histogram using the hue channel in HSV
# color space. We form our final feature vector for each image by concatenating
# the HOG and color histogram feature vectors.
#
# Roughly speaking, HOG should capture the texture of the image while ignoring
# color information, and the color histogram represents the color of the input
# image while ignoring texture. As a result, we expect that using both together
# ought to work better than using either alone. Verifying this assumption would
# be a good thing to try for your own interest.
#
# The `hog_feature` and `color_histogram_hsv` functions both operate on a single
# image and return a feature vector for that image. The extract_features
# function takes a set of images and a list of feature functions and evaluates
# each feature function on each image, storing the results in a matrix where
# each column is the concatenation of all feature vectors for a single image.

# %%
from cs231n.features import *

num_color_bins = 10 # Number of bins in the color histogram
feature_fns = [hog_feature, lambda img: color_histogram_hsv(img, nbin=num_color_bins)]
X_train_feats = extract_features(X_train, feature_fns, verbose=True)
X_val_feats = extract_features(X_val, feature_fns)
X_test_feats = extract_features(X_test, feature_fns)

# Preprocessing: Subtract the mean feature
mean_feat = np.mean(X_train_feats, axis=0, keepdims=True)
X_train_feats -= mean_feat
X_val_feats -= mean_feat
X_test_feats -= mean_feat

# Preprocessing: Divide by standard deviation. This ensures that each feature
# has roughly the same scale.
std_feat = np.std(X_train_feats, axis=0, keepdims=True)
X_train_feats /= std_feat
X_val_feats /= std_feat
X_test_feats /= std_feat

# Preprocessing: Add a bias dimension
X_train_feats = np.hstack([X_train_feats, np.ones((X_train_feats.shape[0], 1))])
X_val_feats = np.hstack([X_val_feats, np.ones((X_val_feats.shape[0], 1))])
X_test_feats = np.hstack([X_test_feats, np.ones((X_test_feats.shape[0], 1))])
# Out:
# Done extracting features for 1000 / 49000 images
# Done extracting features for 2000 / 49000 images
# Done extracting features for 3000 / 49000 images
# Done extracting features for 4000 / 49000 images
# Done extracting features for 5000 / 49000 images
# Done extracting features for 6000 / 49000 images
# Done extracting features for 7000 / 49000 images
# Done extracting features for 8000 / 49000 images
# Done extracting features for 9000 / 49000 images
# Done extracting features for 10000 / 49000 images
# Done extracting features for 11000 / 49000 images
# Done extracting features for 12000 / 49000 images
# Done extracting features for 13000 / 49000 images
# Done extracting features for 14000 / 49000 images
# Done extracting features for 15000 / 49000 images
# Done extracting features for 16000 / 49000 images
# Done extracting features for 17000 / 49000 images
# Done extracting features for 18000 / 49000 images
# Done extracting features for 19000 / 49000 images
# Done extracting features for 20000 / 49000 images
# Done extracting features for 21000 / 49000 images
# Done extracting features for 22000 / 49000 images
# Done extracting features for 23000 / 49000 images
# Done extracting features for 24000 / 49000 images
# Done extracting features for 25000 / 49000 images
# Done extracting features for 26000 / 49000 images
# Done extracting features for 27000 / 49000 images
# Done extracting features for 28000 / 49000 images
# Done extracting features for 29000 / 49000 images
# Done extracting features for 30000 / 49000 images
# Done extracting features for 31000 / 49000 images
# Done extracting features for 32000 / 49000 images
# Done extracting features for 33000 / 49000 images
# Done extracting features for 34000 / 49000 images
# Done extracting features for 35000 / 49000 images
# Done extracting features for 36000 / 49000 images
# Done extracting features for 37000 / 49000 images
# Done extracting features for 38000 / 49000 images
# Done extracting features for 39000 / 49000 images
# Done extracting features for 40000 / 49000 images
# Done extracting features for 41000 / 49000 images
# Done extracting features for 42000 / 49000 images
# Done extracting features for 43000 / 49000 images
# Done extracting features for 44000 / 49000 images
# Done extracting features for 45000 / 49000 images
# Done extracting features for 46000 / 49000 images
# Done extracting features for 47000 / 49000 images
# Done extracting features for 48000 / 49000 images
# Done extracting features for 49000 / 49000 images

# %% [markdown]
# ## Train SVM on features
# Using the multiclass SVM code developed earlier in the assignment, train SVMs on top of the features extracted above; this should achieve better results than training SVMs directly on top of raw pixels.

# %%
# Use the validation set to tune the learning rate and regularization strength

from cs231n.classifiers.linear_classifier import LinearSVM
learning_rates = [1e-9, 1e-8, 1e-7]
regularization_strengths = [5e4, 5e5, 5e6]

results = {}
best_val = -1
best_svm = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained classifer in best_svm. You might also want to play          #
# with different numbers of bins in the color histogram. If you are careful    #
# you should be able to get accuracy of near 0.44 on the validation set.       #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

for lr in learning_rates:
  for reg in regularization_strengths:
    model = LinearSVM()
    loss_hist = model.train(X_train_feats, y_train, learning_rate=lr, reg=reg,
                      num_iters= 1000,  verbose=True)
    
    y_train_pred = model.predict(X_train_feats)
    y_val_pred = model.predict(X_val_feats)

    current_y_train_acc = np.mean(y_train_pred == y_train)
    current_y_val_acc = np.mean(y_val_pred == y_val)

    # storing results
    results[(lr, reg)] = (current_y_train_acc, current_y_val_acc)

    if current_y_val_acc > best_val :
      best_val = current_y_val_acc
      best_svm = model
  

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 89.664728
# iteration 100 / 1000: loss 88.046095
# iteration 200 / 1000: loss 86.497350
# iteration 300 / 1000: loss 84.957829
# iteration 400 / 1000: loss 83.439385
# iteration 500 / 1000: loss 81.988372
# iteration 600 / 1000: loss 80.538579
# iteration 700 / 1000: loss 79.107760
# iteration 800 / 1000: loss 77.727990
# iteration 900 / 1000: loss 76.377840
# iteration 0 / 1000: loss 766.733817
# iteration 100 / 1000: loss 629.318381
# iteration 200 / 1000: loss 516.819464
# iteration 300 / 1000: loss 424.738248
# iteration 400 / 1000: loss 349.337010
# iteration 500 / 1000: loss 287.610326
# iteration 600 / 1000: loss 237.083598
# iteration 700 / 1000: loss 195.723721
# iteration 800 / 1000: loss 161.860118
# iteration 900 / 1000: loss 134.139695
# iteration 0 / 1000: loss 7882.370451
# iteration 100 / 1000: loss 1063.871654
# iteration 200 / 1000: loss 150.332880
# iteration 300 / 1000: loss 27.935227
# iteration 400 / 1000: loss 11.537166
# iteration 500 / 1000: loss 9.339916
# iteration 600 / 1000: loss 9.045583
# iteration 700 / 1000: loss 9.006108
# iteration 800 / 1000: loss 9.000814
# iteration 900 / 1000: loss 9.000107
# iteration 0 / 1000: loss 81.953814
# iteration 100 / 1000: loss 68.728511
# iteration 200 / 1000: loss 57.893767
# iteration 300 / 1000: loss 49.027186
# iteration 400 / 1000: loss 41.770122
# iteration 500 / 1000: loss 35.819428
# iteration 600 / 1000: loss 30.950281
# iteration 700 / 1000: loss 26.974896
# iteration 800 / 1000: loss 23.709513
# iteration 900 / 1000: loss 21.049653
# iteration 0 / 1000: loss 772.957392
# iteration 100 / 1000: loss 111.352329
# iteration 200 / 1000: loss 22.713503
# iteration 300 / 1000: loss 10.837771
# iteration 400 / 1000: loss 9.245993
# iteration 500 / 1000: loss 9.032989
# iteration 600 / 1000: loss 9.004395
# iteration 700 / 1000: loss 9.000541
# iteration 800 / 1000: loss 9.000048
# iteration 900 / 1000: loss 8.999981
# iteration 0 / 1000: loss 7916.599296
# iteration 100 / 1000: loss 9.000002
# iteration 200 / 1000: loss 8.999997
# iteration 300 / 1000: loss 8.999996
# iteration 400 / 1000: loss 8.999997
# iteration 500 / 1000: loss 8.999997
# iteration 600 / 1000: loss 8.999996
# iteration 700 / 1000: loss 8.999997
# iteration 800 / 1000: loss 8.999996
# iteration 900 / 1000: loss 8.999997
# iteration 0 / 1000: loss 87.311202
# iteration 100 / 1000: loss 19.492797
# iteration 200 / 1000: loss 10.405331
# iteration 300 / 1000: loss 9.188494
# iteration 400 / 1000: loss 9.025241
# iteration 500 / 1000: loss 9.002914
# iteration 600 / 1000: loss 9.000137
# iteration 700 / 1000: loss 8.999738
# iteration 800 / 1000: loss 8.999681
# iteration 900 / 1000: loss 8.999627
# iteration 0 / 1000: loss 804.785738
# iteration 100 / 1000: loss 8.999978
# iteration 200 / 1000: loss 8.999968
# iteration 300 / 1000: loss 8.999962
# iteration 400 / 1000: loss 8.999962
# iteration 500 / 1000: loss 8.999971
# iteration 600 / 1000: loss 8.999969
# iteration 700 / 1000: loss 8.999970
# iteration 800 / 1000: loss 8.999964
# iteration 900 / 1000: loss 8.999972
# iteration 0 / 1000: loss 7898.274440
# iteration 100 / 1000: loss 8.999999
# iteration 200 / 1000: loss 8.999999
# iteration 300 / 1000: loss 9.000000
# iteration 400 / 1000: loss 9.000000
# iteration 500 / 1000: loss 8.999999
# iteration 600 / 1000: loss 9.000000
# iteration 700 / 1000: loss 9.000000
# iteration 800 / 1000: loss 9.000000
# iteration 900 / 1000: loss 9.000000
# lr 1.000000e-09 reg 5.000000e+04 train accuracy: 0.098592 val accuracy: 0.090000
# lr 1.000000e-09 reg 5.000000e+05 train accuracy: 0.091592 val accuracy: 0.089000
# lr 1.000000e-09 reg 5.000000e+06 train accuracy: 0.299061 val accuracy: 0.320000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.106000 val accuracy: 0.120000
# lr 1.000000e-08 reg 5.000000e+05 train accuracy: 0.415184 val accuracy: 0.423000
# lr 1.000000e-08 reg 5.000000e+06 train accuracy: 0.407245 val accuracy: 0.419000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.414959 val accuracy: 0.410000
# lr 1.000000e-07 reg 5.000000e+05 train accuracy: 0.412980 val accuracy: 0.412000
# lr 1.000000e-07 reg 5.000000e+06 train accuracy: 0.316653 val accuracy: 0.319000
# best validation accuracy achieved: 0.423000

# %%
# Evaluate your trained SVM on the test set: you should be able to get at least 0.40
y_test_pred = best_svm.predict(X_test_feats)
test_accuracy = np.mean(y_test == y_test_pred)
print(test_accuracy)
# Out:
# 0.41

# %%
# An important way to gain intuition about how an algorithm works is to
# visualize the mistakes that it makes. In this visualization, we show examples
# of images that are misclassified by our current system. The first column
# shows images that our system labeled as "plane" but whose true label is
# something other than "plane".

examples_per_class = 8
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for cls, cls_name in enumerate(classes):
    idxs = np.where((y_test != cls) & (y_test_pred == cls))[0]
    idxs = np.random.choice(idxs, examples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt.subplot(examples_per_class, len(classes), i * len(classes) + cls + 1)
        plt.imshow(X_test[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls_name)
plt.show()

# %% [markdown]
# ### Inline question 1:
# Describe the misclassification results that you see. Do they make sense?
#
#
# $\color{blue}{\textit Your Answer:}$
#
# 동물의 경우 얼굴, 눈코입, 다리 등이 있기 때문에 같은 '동물'이라는 카테고리 안에서는 분류가 어느 정도 되었지만,
#
# 그 동물이 cat인지 dog인지 horse인지 세세하게 분류하지는 못한 것 같다.
#
# 운송수단의 경우에도 마찬가지로 '운송수단'이라는 큰 카테고리 안에서는 분류를 잘 하였지만,
#
# 새를 plane으로 분류한다던가, 아니면 car를 truck으로 분류한다던가 하는 오분류가 상당히 있다.
#
# 따라서 HOG(texture를 반영하지만, 회전, 확대/축소, 스케일링 등에 취약함)와 color histogram을 이어 붙이는 것보다 더 좋은 feature extraction 방법을 적용하는 것이 바람직하다.

# %% [markdown]
# ## Neural Network on image features
# Earlier in this assigment we saw that training a two-layer neural network on raw pixels achieved better classification performance than linear classifiers on raw pixels. In this notebook we have seen that linear classifiers on image features outperform linear classifiers on raw pixels.
#
# For completeness, we should also try training a neural network on image features. This approach should outperform all previous approaches: you should easily be able to achieve over 55% classification accuracy on the test set; our best model achieves about 60% classification accuracy.

# %%
# Preprocessing: Remove the bias dimension
# Make sure to run this cell only ONCE
print(X_train_feats.shape)
X_train_feats = X_train_feats[:, :-1]
X_val_feats = X_val_feats[:, :-1]
X_test_feats = X_test_feats[:, :-1]

print(X_train_feats.shape)
# Out:
# (49000, 155)
# (49000, 154)

# %%
print(X_train_feats.shape,
      X_val_feats.shape,
      y_train.shape,
      y_val.shape)
# Out:
# (49000, 154) (1000, 154) (49000,) (1000,)

# %%
from cs231n.classifiers.fc_net import TwoLayerNet
from cs231n.solver import Solver

input_dim = X_train_feats.shape[1]
num_classes = 10

best_net = None

################################################################################
# TODO: Train a two-layer neural network on image features. You may want to    #
# cross-validate various parameters as in previous sections. Store your best   #
# model in the best_net variable.                                              #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
'''
 # Random Search
for i in range(20):
  hidden_size = int(np.rint(10 ** np.random.uniform(2, 3)))
  lr = 10 ** np.random.uniform(-2, 0)
  ws = 10 ** np.random.uniform(-3, -1)
  reg = 10 ** np.random.uniform(-2, 2)
 ''' 
hidden_sizes = [10, 100, 500, 1000]
lrs = [0.01, 0.1, 1.0]
regs = [0.0, 0.01, 0.1, 1.0]

for hidden_size in hidden_sizes :
  for lr in lrs :
    for reg in regs : 

      print("**********************************")
      print("hidden layer dim: %d, lr: %.4f, reg: %.4f" %(hidden_size, lr, reg))
      
      model = TwoLayerNet(input_dim = input_dim, # input_dim이 변경되었으므로 바꿔줌.
                          hidden_dim = hidden_size, 
                          reg = reg
                          )
      
      solver = Solver(model = model,
                      data = {'X_train' : X_train_feats,
                              'X_val' : X_val_feats,
                              'y_train' : y_train,
                              'y_val' : y_val
                              },
                      update_rule = 'sgd',
                      optim_config = {
                          'learning_rate': lr
                          },
                      lr_decay=0.95,
                      num_epochs = 20, 
                      batch_size = 100,
                      print_every = 1000)
      solver.train()
      val_accuracy = solver.best_val_acc
      if best_val < val_accuracy:
        best_val = val_accuracy
        best_net = model
        
print('best validation accuracy : %f' % best_val)
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
# Out:
# **********************************
# hidden layer dim: 10, lr: 0.0100, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302587
# (Epoch 0 / 20) train acc: 0.094000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.104000; val_acc: 0.087000
# (Epoch 2 / 20) train acc: 0.151000; val_acc: 0.120000
# (Iteration 1001 / 9800) loss: 2.301315
# (Epoch 3 / 20) train acc: 0.187000; val_acc: 0.179000
# (Epoch 4 / 20) train acc: 0.199000; val_acc: 0.216000
# (Iteration 2001 / 9800) loss: 2.079095
# (Epoch 5 / 20) train acc: 0.301000; val_acc: 0.279000
# (Epoch 6 / 20) train acc: 0.279000; val_acc: 0.288000
# (Iteration 3001 / 9800) loss: 1.901509
# (Epoch 7 / 20) train acc: 0.317000; val_acc: 0.292000
# (Epoch 8 / 20) train acc: 0.336000; val_acc: 0.318000
# (Iteration 4001 / 9800) loss: 1.760180
# (Epoch 9 / 20) train acc: 0.357000; val_acc: 0.321000
# (Epoch 10 / 20) train acc: 0.362000; val_acc: 0.348000
# (Iteration 5001 / 9800) loss: 1.649996
# (Epoch 11 / 20) train acc: 0.415000; val_acc: 0.380000
# (Epoch 12 / 20) train acc: 0.394000; val_acc: 0.376000
# (Iteration 6001 / 9800) loss: 1.417041
# (Epoch 13 / 20) train acc: 0.421000; val_acc: 0.396000
# (Epoch 14 / 20) train acc: 0.390000; val_acc: 0.400000
# (Iteration 7001 / 9800) loss: 1.453494
# (Epoch 15 / 20) train acc: 0.435000; val_acc: 0.416000
# (Epoch 16 / 20) train acc: 0.450000; val_acc: 0.427000
# (Iteration 8001 / 9800) loss: 1.524648
# (Epoch 17 / 20) train acc: 0.437000; val_acc: 0.439000
# (Epoch 18 / 20) train acc: 0.442000; val_acc: 0.448000
# (Iteration 9001 / 9800) loss: 1.544735
# (Epoch 19 / 20) train acc: 0.466000; val_acc: 0.453000
# (Epoch 20 / 20) train acc: 0.428000; val_acc: 0.460000
# **********************************
# hidden layer dim: 10, lr: 0.0100, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.302593
# (Epoch 0 / 20) train acc: 0.105000; val_acc: 0.102000
# (Epoch 1 / 20) train acc: 0.094000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.096000; val_acc: 0.087000
# (Iteration 1001 / 9800) loss: 2.300992
# (Epoch 3 / 20) train acc: 0.196000; val_acc: 0.184000
# (Epoch 4 / 20) train acc: 0.220000; val_acc: 0.213000
# (Iteration 2001 / 9800) loss: 2.121538
# (Epoch 5 / 20) train acc: 0.278000; val_acc: 0.302000
# (Epoch 6 / 20) train acc: 0.313000; val_acc: 0.323000
# (Iteration 3001 / 9800) loss: 1.815874
# (Epoch 7 / 20) train acc: 0.346000; val_acc: 0.331000
# (Epoch 8 / 20) train acc: 0.386000; val_acc: 0.372000
# (Iteration 4001 / 9800) loss: 1.834842
# (Epoch 9 / 20) train acc: 0.380000; val_acc: 0.374000
# (Epoch 10 / 20) train acc: 0.380000; val_acc: 0.391000
# (Iteration 5001 / 9800) loss: 1.710675
# (Epoch 11 / 20) train acc: 0.419000; val_acc: 0.404000
# (Epoch 12 / 20) train acc: 0.418000; val_acc: 0.425000
# (Iteration 6001 / 9800) loss: 1.649676
# (Epoch 13 / 20) train acc: 0.455000; val_acc: 0.441000
# (Epoch 14 / 20) train acc: 0.447000; val_acc: 0.449000
# (Iteration 7001 / 9800) loss: 1.436394
# (Epoch 15 / 20) train acc: 0.448000; val_acc: 0.457000
# (Epoch 16 / 20) train acc: 0.441000; val_acc: 0.466000
# (Iteration 8001 / 9800) loss: 1.671168
# (Epoch 17 / 20) train acc: 0.440000; val_acc: 0.468000
# (Epoch 18 / 20) train acc: 0.437000; val_acc: 0.475000
# (Iteration 9001 / 9800) loss: 1.648817
# (Epoch 19 / 20) train acc: 0.443000; val_acc: 0.471000
# (Epoch 20 / 20) train acc: 0.458000; val_acc: 0.480000
# **********************************
# hidden layer dim: 10, lr: 0.0100, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.302667
# (Epoch 0 / 20) train acc: 0.115000; val_acc: 0.072000
# (Epoch 1 / 20) train acc: 0.096000; val_acc: 0.113000
# (Epoch 2 / 20) train acc: 0.085000; val_acc: 0.113000
# (Iteration 1001 / 9800) loss: 2.303340
# (Epoch 3 / 20) train acc: 0.105000; val_acc: 0.087000
# (Epoch 4 / 20) train acc: 0.132000; val_acc: 0.117000
# (Iteration 2001 / 9800) loss: 2.300265
# (Epoch 5 / 20) train acc: 0.194000; val_acc: 0.203000
# (Epoch 6 / 20) train acc: 0.221000; val_acc: 0.211000
# (Iteration 3001 / 9800) loss: 2.246376
# (Epoch 7 / 20) train acc: 0.199000; val_acc: 0.241000
# (Epoch 8 / 20) train acc: 0.232000; val_acc: 0.252000
# (Iteration 4001 / 9800) loss: 2.210664
# (Epoch 9 / 20) train acc: 0.276000; val_acc: 0.268000
# (Epoch 10 / 20) train acc: 0.253000; val_acc: 0.276000
# (Iteration 5001 / 9800) loss: 2.068055
# (Epoch 11 / 20) train acc: 0.268000; val_acc: 0.286000
# (Epoch 12 / 20) train acc: 0.292000; val_acc: 0.295000
# (Iteration 6001 / 9800) loss: 2.113152
# (Epoch 13 / 20) train acc: 0.271000; val_acc: 0.302000
# (Epoch 14 / 20) train acc: 0.281000; val_acc: 0.307000
# (Iteration 7001 / 9800) loss: 2.115054
# (Epoch 15 / 20) train acc: 0.324000; val_acc: 0.317000
# (Epoch 16 / 20) train acc: 0.324000; val_acc: 0.317000
# (Iteration 8001 / 9800) loss: 2.075576
# (Epoch 17 / 20) train acc: 0.315000; val_acc: 0.326000
# (Epoch 18 / 20) train acc: 0.329000; val_acc: 0.334000
# (Iteration 9001 / 9800) loss: 2.078762
# (Epoch 19 / 20) train acc: 0.350000; val_acc: 0.332000
# (Epoch 20 / 20) train acc: 0.359000; val_acc: 0.347000
# **********************************
# hidden layer dim: 10, lr: 0.0100, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.303450
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.105000
# (Epoch 1 / 20) train acc: 0.094000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.099000; val_acc: 0.098000
# (Iteration 1001 / 9800) loss: 2.301321
# (Epoch 3 / 20) train acc: 0.120000; val_acc: 0.098000
# (Epoch 4 / 20) train acc: 0.091000; val_acc: 0.098000
# (Iteration 2001 / 9800) loss: 2.302301
# (Epoch 5 / 20) train acc: 0.097000; val_acc: 0.113000
# (Epoch 6 / 20) train acc: 0.090000; val_acc: 0.113000
# (Iteration 3001 / 9800) loss: 2.301871
# (Epoch 7 / 20) train acc: 0.102000; val_acc: 0.079000
# (Epoch 8 / 20) train acc: 0.090000; val_acc: 0.105000
# (Iteration 4001 / 9800) loss: 2.302610
# (Epoch 9 / 20) train acc: 0.102000; val_acc: 0.105000
# (Epoch 10 / 20) train acc: 0.086000; val_acc: 0.105000
# (Iteration 5001 / 9800) loss: 2.302025
# (Epoch 11 / 20) train acc: 0.088000; val_acc: 0.098000
# (Epoch 12 / 20) train acc: 0.097000; val_acc: 0.098000
# (Iteration 6001 / 9800) loss: 2.302655
# (Epoch 13 / 20) train acc: 0.099000; val_acc: 0.078000
# (Epoch 14 / 20) train acc: 0.113000; val_acc: 0.098000
# (Iteration 7001 / 9800) loss: 2.303303
# (Epoch 15 / 20) train acc: 0.110000; val_acc: 0.112000
# (Epoch 16 / 20) train acc: 0.100000; val_acc: 0.112000
# (Iteration 8001 / 9800) loss: 2.302624
# (Epoch 17 / 20) train acc: 0.095000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.101000; val_acc: 0.078000
# (Iteration 9001 / 9800) loss: 2.303369
# (Epoch 19 / 20) train acc: 0.096000; val_acc: 0.078000
# (Epoch 20 / 20) train acc: 0.108000; val_acc: 0.078000
# **********************************
# hidden layer dim: 10, lr: 0.1000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302591
# (Epoch 0 / 20) train acc: 0.091000; val_acc: 0.119000
# (Epoch 1 / 20) train acc: 0.444000; val_acc: 0.425000
# (Epoch 2 / 20) train acc: 0.490000; val_acc: 0.480000
# (Iteration 1001 / 9800) loss: 1.389418
# (Epoch 3 / 20) train acc: 0.517000; val_acc: 0.502000
# (Epoch 4 / 20) train acc: 0.518000; val_acc: 0.493000
# (Iteration 2001 / 9800) loss: 1.638414
# (Epoch 5 / 20) train acc: 0.529000; val_acc: 0.505000
# (Epoch 6 / 20) train acc: 0.510000; val_acc: 0.493000
# (Iteration 3001 / 9800) loss: 1.430900
# (Epoch 7 / 20) train acc: 0.527000; val_acc: 0.500000
# (Epoch 8 / 20) train acc: 0.533000; val_acc: 0.493000
# (Iteration 4001 / 9800) loss: 1.481178
# (Epoch 9 / 20) train acc: 0.502000; val_acc: 0.493000
# (Epoch 10 / 20) train acc: 0.528000; val_acc: 0.501000
# (Iteration 5001 / 9800) loss: 1.309681
# (Epoch 11 / 20) train acc: 0.552000; val_acc: 0.495000
# (Epoch 12 / 20) train acc: 0.510000; val_acc: 0.498000
# (Iteration 6001 / 9800) loss: 1.491177
# (Epoch 13 / 20) train acc: 0.506000; val_acc: 0.493000
# (Epoch 14 / 20) train acc: 0.495000; val_acc: 0.508000
# (Iteration 7001 / 9800) loss: 1.523650
# (Epoch 15 / 20) train acc: 0.516000; val_acc: 0.504000
# (Epoch 16 / 20) train acc: 0.535000; val_acc: 0.511000
# (Iteration 8001 / 9800) loss: 1.411414
# (Epoch 17 / 20) train acc: 0.508000; val_acc: 0.505000
# (Epoch 18 / 20) train acc: 0.530000; val_acc: 0.498000
# (Iteration 9001 / 9800) loss: 1.481004
# (Epoch 19 / 20) train acc: 0.549000; val_acc: 0.495000
# (Epoch 20 / 20) train acc: 0.543000; val_acc: 0.503000
# **********************************
# hidden layer dim: 10, lr: 0.1000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.302591
# (Epoch 0 / 20) train acc: 0.103000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.430000; val_acc: 0.395000
# (Epoch 2 / 20) train acc: 0.469000; val_acc: 0.479000
# (Iteration 1001 / 9800) loss: 1.435337
# (Epoch 3 / 20) train acc: 0.524000; val_acc: 0.484000
# (Epoch 4 / 20) train acc: 0.521000; val_acc: 0.497000
# (Iteration 2001 / 9800) loss: 1.449363
# (Epoch 5 / 20) train acc: 0.511000; val_acc: 0.498000
# (Epoch 6 / 20) train acc: 0.532000; val_acc: 0.499000
# (Iteration 3001 / 9800) loss: 1.723438
# (Epoch 7 / 20) train acc: 0.523000; val_acc: 0.494000
# (Epoch 8 / 20) train acc: 0.500000; val_acc: 0.510000
# (Iteration 4001 / 9800) loss: 1.326053
# (Epoch 9 / 20) train acc: 0.515000; val_acc: 0.495000
# (Epoch 10 / 20) train acc: 0.473000; val_acc: 0.499000
# (Iteration 5001 / 9800) loss: 1.550105
# (Epoch 11 / 20) train acc: 0.521000; val_acc: 0.504000
# (Epoch 12 / 20) train acc: 0.513000; val_acc: 0.496000
# (Iteration 6001 / 9800) loss: 1.442340
# (Epoch 13 / 20) train acc: 0.512000; val_acc: 0.508000
# (Epoch 14 / 20) train acc: 0.526000; val_acc: 0.505000
# (Iteration 7001 / 9800) loss: 1.401021
# (Epoch 15 / 20) train acc: 0.537000; val_acc: 0.498000
# (Epoch 16 / 20) train acc: 0.530000; val_acc: 0.511000
# (Iteration 8001 / 9800) loss: 1.562181
# (Epoch 17 / 20) train acc: 0.507000; val_acc: 0.505000
# (Epoch 18 / 20) train acc: 0.523000; val_acc: 0.509000
# (Iteration 9001 / 9800) loss: 1.370903
# (Epoch 19 / 20) train acc: 0.498000; val_acc: 0.506000
# (Epoch 20 / 20) train acc: 0.531000; val_acc: 0.500000
# **********************************
# hidden layer dim: 10, lr: 0.1000, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.302671
# (Epoch 0 / 20) train acc: 0.104000; val_acc: 0.129000
# (Epoch 1 / 20) train acc: 0.278000; val_acc: 0.298000
# (Epoch 2 / 20) train acc: 0.399000; val_acc: 0.398000
# (Iteration 1001 / 9800) loss: 2.023946
# (Epoch 3 / 20) train acc: 0.465000; val_acc: 0.436000
# (Epoch 4 / 20) train acc: 0.422000; val_acc: 0.413000
# (Iteration 2001 / 9800) loss: 1.989528
# (Epoch 5 / 20) train acc: 0.438000; val_acc: 0.443000
# (Epoch 6 / 20) train acc: 0.434000; val_acc: 0.423000
# (Iteration 3001 / 9800) loss: 1.999409
# (Epoch 7 / 20) train acc: 0.404000; val_acc: 0.427000
# (Epoch 8 / 20) train acc: 0.424000; val_acc: 0.437000
# (Iteration 4001 / 9800) loss: 1.852582
# (Epoch 9 / 20) train acc: 0.413000; val_acc: 0.426000
# (Epoch 10 / 20) train acc: 0.413000; val_acc: 0.412000
# (Iteration 5001 / 9800) loss: 1.907336
# (Epoch 11 / 20) train acc: 0.433000; val_acc: 0.442000
# (Epoch 12 / 20) train acc: 0.447000; val_acc: 0.438000
# (Iteration 6001 / 9800) loss: 1.882495
# (Epoch 13 / 20) train acc: 0.428000; val_acc: 0.437000
# (Epoch 14 / 20) train acc: 0.442000; val_acc: 0.425000
# (Iteration 7001 / 9800) loss: 1.913035
# (Epoch 15 / 20) train acc: 0.409000; val_acc: 0.423000
# (Epoch 16 / 20) train acc: 0.443000; val_acc: 0.428000
# (Iteration 8001 / 9800) loss: 1.900376
# (Epoch 17 / 20) train acc: 0.442000; val_acc: 0.443000
# (Epoch 18 / 20) train acc: 0.447000; val_acc: 0.436000
# (Iteration 9001 / 9800) loss: 1.963933
# (Epoch 19 / 20) train acc: 0.413000; val_acc: 0.432000
# (Epoch 20 / 20) train acc: 0.428000; val_acc: 0.425000
# **********************************
# hidden layer dim: 10, lr: 0.1000, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.303460
# (Epoch 0 / 20) train acc: 0.096000; val_acc: 0.098000
# (Epoch 1 / 20) train acc: 0.099000; val_acc: 0.087000
# (Epoch 2 / 20) train acc: 0.096000; val_acc: 0.112000
# (Iteration 1001 / 9800) loss: 2.303467
# (Epoch 3 / 20) train acc: 0.078000; val_acc: 0.098000
# (Epoch 4 / 20) train acc: 0.089000; val_acc: 0.113000
# (Iteration 2001 / 9800) loss: 2.300869
# (Epoch 5 / 20) train acc: 0.098000; val_acc: 0.079000
# (Epoch 6 / 20) train acc: 0.097000; val_acc: 0.087000
# (Iteration 3001 / 9800) loss: 2.304505
# (Epoch 7 / 20) train acc: 0.099000; val_acc: 0.079000
# (Epoch 8 / 20) train acc: 0.099000; val_acc: 0.087000
# (Iteration 4001 / 9800) loss: 2.307213
# (Epoch 9 / 20) train acc: 0.110000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.119000; val_acc: 0.078000
# (Iteration 5001 / 9800) loss: 2.303793
# (Epoch 11 / 20) train acc: 0.107000; val_acc: 0.079000
# (Epoch 12 / 20) train acc: 0.108000; val_acc: 0.105000
# (Iteration 6001 / 9800) loss: 2.300970
# (Epoch 13 / 20) train acc: 0.094000; val_acc: 0.078000
# (Epoch 14 / 20) train acc: 0.086000; val_acc: 0.112000
# (Iteration 7001 / 9800) loss: 2.301387
# (Epoch 15 / 20) train acc: 0.099000; val_acc: 0.102000
# (Epoch 16 / 20) train acc: 0.120000; val_acc: 0.105000
# (Iteration 8001 / 9800) loss: 2.302058
# (Epoch 17 / 20) train acc: 0.099000; val_acc: 0.098000
# (Epoch 18 / 20) train acc: 0.099000; val_acc: 0.107000
# (Iteration 9001 / 9800) loss: 2.302319
# (Epoch 19 / 20) train acc: 0.089000; val_acc: 0.105000
# (Epoch 20 / 20) train acc: 0.105000; val_acc: 0.102000
# **********************************
# hidden layer dim: 10, lr: 1.0000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302585
# (Epoch 0 / 20) train acc: 0.101000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.464000; val_acc: 0.410000
# (Epoch 2 / 20) train acc: 0.469000; val_acc: 0.460000
# (Iteration 1001 / 9800) loss: 1.684257
# (Epoch 3 / 20) train acc: 0.516000; val_acc: 0.456000
# (Epoch 4 / 20) train acc: 0.466000; val_acc: 0.476000
# (Iteration 2001 / 9800) loss: 1.626976
# (Epoch 5 / 20) train acc: 0.477000; val_acc: 0.470000
# (Epoch 6 / 20) train acc: 0.486000; val_acc: 0.430000
# (Iteration 3001 / 9800) loss: 1.393839
# (Epoch 7 / 20) train acc: 0.498000; val_acc: 0.462000
# (Epoch 8 / 20) train acc: 0.509000; val_acc: 0.477000
# (Iteration 4001 / 9800) loss: 1.538658
# (Epoch 9 / 20) train acc: 0.465000; val_acc: 0.477000
# (Epoch 10 / 20) train acc: 0.469000; val_acc: 0.464000
# (Iteration 5001 / 9800) loss: 1.418774
# (Epoch 11 / 20) train acc: 0.478000; val_acc: 0.458000
# (Epoch 12 / 20) train acc: 0.479000; val_acc: 0.446000
# (Iteration 6001 / 9800) loss: 1.415218
# (Epoch 13 / 20) train acc: 0.477000; val_acc: 0.474000
# (Epoch 14 / 20) train acc: 0.509000; val_acc: 0.480000
# (Iteration 7001 / 9800) loss: 1.522050
# (Epoch 15 / 20) train acc: 0.505000; val_acc: 0.487000
# (Epoch 16 / 20) train acc: 0.477000; val_acc: 0.484000
# (Iteration 8001 / 9800) loss: 1.609303
# (Epoch 17 / 20) train acc: 0.482000; val_acc: 0.485000
# (Epoch 18 / 20) train acc: 0.499000; val_acc: 0.478000
# (Iteration 9001 / 9800) loss: 1.355792
# (Epoch 19 / 20) train acc: 0.492000; val_acc: 0.484000
# (Epoch 20 / 20) train acc: 0.524000; val_acc: 0.490000
# **********************************
# hidden layer dim: 10, lr: 1.0000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.302591
# (Epoch 0 / 20) train acc: 0.108000; val_acc: 0.105000
# (Epoch 1 / 20) train acc: 0.405000; val_acc: 0.418000
# (Epoch 2 / 20) train acc: 0.461000; val_acc: 0.459000
# (Iteration 1001 / 9800) loss: 1.746527
# (Epoch 3 / 20) train acc: 0.475000; val_acc: 0.454000
# (Epoch 4 / 20) train acc: 0.466000; val_acc: 0.445000
# (Iteration 2001 / 9800) loss: 1.663148
# (Epoch 5 / 20) train acc: 0.437000; val_acc: 0.470000
# (Epoch 6 / 20) train acc: 0.465000; val_acc: 0.461000
# (Iteration 3001 / 9800) loss: 1.679118
# (Epoch 7 / 20) train acc: 0.468000; val_acc: 0.464000
# (Epoch 8 / 20) train acc: 0.426000; val_acc: 0.455000
# (Iteration 4001 / 9800) loss: 1.565333
# (Epoch 9 / 20) train acc: 0.454000; val_acc: 0.456000
# (Epoch 10 / 20) train acc: 0.477000; val_acc: 0.461000
# (Iteration 5001 / 9800) loss: 1.415370
# (Epoch 11 / 20) train acc: 0.508000; val_acc: 0.455000
# (Epoch 12 / 20) train acc: 0.444000; val_acc: 0.449000
# (Iteration 6001 / 9800) loss: 1.548151
# (Epoch 13 / 20) train acc: 0.466000; val_acc: 0.449000
# (Epoch 14 / 20) train acc: 0.472000; val_acc: 0.476000
# (Iteration 7001 / 9800) loss: 1.701901
# (Epoch 15 / 20) train acc: 0.495000; val_acc: 0.487000
# (Epoch 16 / 20) train acc: 0.484000; val_acc: 0.476000
# (Iteration 8001 / 9800) loss: 1.521102
# (Epoch 17 / 20) train acc: 0.489000; val_acc: 0.491000
# (Epoch 18 / 20) train acc: 0.509000; val_acc: 0.493000
# (Iteration 9001 / 9800) loss: 1.589329
# (Epoch 19 / 20) train acc: 0.495000; val_acc: 0.470000
# (Epoch 20 / 20) train acc: 0.479000; val_acc: 0.487000
# **********************************
# hidden layer dim: 10, lr: 1.0000, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.302662
# (Epoch 0 / 20) train acc: 0.096000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.289000; val_acc: 0.279000
# (Epoch 2 / 20) train acc: 0.379000; val_acc: 0.399000
# (Iteration 1001 / 9800) loss: 2.042659
# (Epoch 3 / 20) train acc: 0.329000; val_acc: 0.342000
# (Epoch 4 / 20) train acc: 0.334000; val_acc: 0.317000
# (Iteration 2001 / 9800) loss: 2.140194
# (Epoch 5 / 20) train acc: 0.351000; val_acc: 0.337000
# (Epoch 6 / 20) train acc: 0.371000; val_acc: 0.338000
# (Iteration 3001 / 9800) loss: 2.108288
# (Epoch 7 / 20) train acc: 0.392000; val_acc: 0.338000
# (Epoch 8 / 20) train acc: 0.339000; val_acc: 0.333000
# (Iteration 4001 / 9800) loss: 2.080562
# (Epoch 9 / 20) train acc: 0.346000; val_acc: 0.324000
# (Epoch 10 / 20) train acc: 0.322000; val_acc: 0.316000
# (Iteration 5001 / 9800) loss: 2.073217
# (Epoch 11 / 20) train acc: 0.363000; val_acc: 0.398000
# (Epoch 12 / 20) train acc: 0.382000; val_acc: 0.370000
# (Iteration 6001 / 9800) loss: 1.878224
# (Epoch 13 / 20) train acc: 0.324000; val_acc: 0.322000
# (Epoch 14 / 20) train acc: 0.399000; val_acc: 0.384000
# (Iteration 7001 / 9800) loss: 1.924215
# (Epoch 15 / 20) train acc: 0.406000; val_acc: 0.409000
# (Epoch 16 / 20) train acc: 0.379000; val_acc: 0.368000
# (Iteration 8001 / 9800) loss: 2.053930
# (Epoch 17 / 20) train acc: 0.371000; val_acc: 0.373000
# (Epoch 18 / 20) train acc: 0.413000; val_acc: 0.396000
# (Iteration 9001 / 9800) loss: 1.993758
# (Epoch 19 / 20) train acc: 0.365000; val_acc: 0.396000
# (Epoch 20 / 20) train acc: 0.385000; val_acc: 0.401000
# **********************************
# hidden layer dim: 10, lr: 1.0000, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.303399
# (Epoch 0 / 20) train acc: 0.089000; val_acc: 0.113000
# (Epoch 1 / 20) train acc: 0.089000; val_acc: 0.113000
# (Epoch 2 / 20) train acc: 0.104000; val_acc: 0.078000
# (Iteration 1001 / 9800) loss: 2.302013
# (Epoch 3 / 20) train acc: 0.110000; val_acc: 0.105000
# (Epoch 4 / 20) train acc: 0.095000; val_acc: 0.105000
# (Iteration 2001 / 9800) loss: 2.301618
# (Epoch 5 / 20) train acc: 0.089000; val_acc: 0.105000
# (Epoch 6 / 20) train acc: 0.102000; val_acc: 0.105000
# (Iteration 3001 / 9800) loss: 2.294639
# (Epoch 7 / 20) train acc: 0.093000; val_acc: 0.105000
# (Epoch 8 / 20) train acc: 0.095000; val_acc: 0.102000
# (Iteration 4001 / 9800) loss: 2.301275
# (Epoch 9 / 20) train acc: 0.088000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.114000; val_acc: 0.113000
# (Iteration 5001 / 9800) loss: 2.307108
# (Epoch 11 / 20) train acc: 0.077000; val_acc: 0.078000
# (Epoch 12 / 20) train acc: 0.110000; val_acc: 0.107000
# (Iteration 6001 / 9800) loss: 2.293945
# (Epoch 13 / 20) train acc: 0.097000; val_acc: 0.098000
# (Epoch 14 / 20) train acc: 0.110000; val_acc: 0.078000
# (Iteration 7001 / 9800) loss: 2.298883
# (Epoch 15 / 20) train acc: 0.096000; val_acc: 0.113000
# (Epoch 16 / 20) train acc: 0.104000; val_acc: 0.102000
# (Iteration 8001 / 9800) loss: 2.305386
# (Epoch 17 / 20) train acc: 0.112000; val_acc: 0.102000
# (Epoch 18 / 20) train acc: 0.124000; val_acc: 0.087000
# (Iteration 9001 / 9800) loss: 2.307418
# (Epoch 19 / 20) train acc: 0.101000; val_acc: 0.079000
# (Epoch 20 / 20) train acc: 0.095000; val_acc: 0.119000
# **********************************
# hidden layer dim: 100, lr: 0.0100, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302592
# (Epoch 0 / 20) train acc: 0.126000; val_acc: 0.125000
# (Epoch 1 / 20) train acc: 0.109000; val_acc: 0.102000
# (Epoch 2 / 20) train acc: 0.247000; val_acc: 0.251000
# (Iteration 1001 / 9800) loss: 2.289186
# (Epoch 3 / 20) train acc: 0.264000; val_acc: 0.245000
# (Epoch 4 / 20) train acc: 0.303000; val_acc: 0.304000
# (Iteration 2001 / 9800) loss: 1.926815
# (Epoch 5 / 20) train acc: 0.342000; val_acc: 0.334000
# (Epoch 6 / 20) train acc: 0.399000; val_acc: 0.372000
# (Iteration 3001 / 9800) loss: 1.654952
# (Epoch 7 / 20) train acc: 0.439000; val_acc: 0.405000
# (Epoch 8 / 20) train acc: 0.426000; val_acc: 0.425000
# (Iteration 4001 / 9800) loss: 1.458293
# (Epoch 9 / 20) train acc: 0.448000; val_acc: 0.439000
# (Epoch 10 / 20) train acc: 0.462000; val_acc: 0.451000
# (Iteration 5001 / 9800) loss: 1.487452
# (Epoch 11 / 20) train acc: 0.471000; val_acc: 0.466000
# (Epoch 12 / 20) train acc: 0.467000; val_acc: 0.464000
# (Iteration 6001 / 9800) loss: 1.543412
# (Epoch 13 / 20) train acc: 0.459000; val_acc: 0.478000
# (Epoch 14 / 20) train acc: 0.476000; val_acc: 0.487000
# (Iteration 7001 / 9800) loss: 1.313729
# (Epoch 15 / 20) train acc: 0.489000; val_acc: 0.487000
# (Epoch 16 / 20) train acc: 0.508000; val_acc: 0.487000
# (Iteration 8001 / 9800) loss: 1.331079
# (Epoch 17 / 20) train acc: 0.491000; val_acc: 0.493000
# (Epoch 18 / 20) train acc: 0.505000; val_acc: 0.497000
# (Iteration 9001 / 9800) loss: 1.304498
# (Epoch 19 / 20) train acc: 0.540000; val_acc: 0.503000
# (Epoch 20 / 20) train acc: 0.540000; val_acc: 0.503000
# **********************************
# hidden layer dim: 100, lr: 0.0100, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.302681
# (Epoch 0 / 20) train acc: 0.089000; val_acc: 0.084000
# (Epoch 1 / 20) train acc: 0.116000; val_acc: 0.078000
# (Epoch 2 / 20) train acc: 0.201000; val_acc: 0.226000
# (Iteration 1001 / 9800) loss: 2.294848
# (Epoch 3 / 20) train acc: 0.217000; val_acc: 0.233000
# (Epoch 4 / 20) train acc: 0.266000; val_acc: 0.268000
# (Iteration 2001 / 9800) loss: 1.986628
# (Epoch 5 / 20) train acc: 0.290000; val_acc: 0.294000
# (Epoch 6 / 20) train acc: 0.361000; val_acc: 0.353000
# (Iteration 3001 / 9800) loss: 1.804311
# (Epoch 7 / 20) train acc: 0.369000; val_acc: 0.386000
# (Epoch 8 / 20) train acc: 0.437000; val_acc: 0.403000
# (Iteration 4001 / 9800) loss: 1.668919
# (Epoch 9 / 20) train acc: 0.455000; val_acc: 0.425000
# (Epoch 10 / 20) train acc: 0.437000; val_acc: 0.437000
# (Iteration 5001 / 9800) loss: 1.490184
# (Epoch 11 / 20) train acc: 0.490000; val_acc: 0.452000
# (Epoch 12 / 20) train acc: 0.494000; val_acc: 0.466000
# (Iteration 6001 / 9800) loss: 1.562944
# (Epoch 13 / 20) train acc: 0.485000; val_acc: 0.479000
# (Epoch 14 / 20) train acc: 0.473000; val_acc: 0.480000
# (Iteration 7001 / 9800) loss: 1.404458
# (Epoch 15 / 20) train acc: 0.493000; val_acc: 0.492000
# (Epoch 16 / 20) train acc: 0.503000; val_acc: 0.484000
# (Iteration 8001 / 9800) loss: 1.413584
# (Epoch 17 / 20) train acc: 0.529000; val_acc: 0.486000
# (Epoch 18 / 20) train acc: 0.493000; val_acc: 0.488000
# (Iteration 9001 / 9800) loss: 1.584341
# (Epoch 19 / 20) train acc: 0.509000; val_acc: 0.490000
# (Epoch 20 / 20) train acc: 0.496000; val_acc: 0.497000
# **********************************
# hidden layer dim: 100, lr: 0.0100, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.303409
# (Epoch 0 / 20) train acc: 0.103000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.116000; val_acc: 0.107000
# (Epoch 2 / 20) train acc: 0.114000; val_acc: 0.106000
# (Iteration 1001 / 9800) loss: 2.304031
# (Epoch 3 / 20) train acc: 0.205000; val_acc: 0.174000
# (Epoch 4 / 20) train acc: 0.227000; val_acc: 0.215000
# (Iteration 2001 / 9800) loss: 2.266417
# (Epoch 5 / 20) train acc: 0.256000; val_acc: 0.256000
# (Epoch 6 / 20) train acc: 0.260000; val_acc: 0.288000
# (Iteration 3001 / 9800) loss: 2.112253
# (Epoch 7 / 20) train acc: 0.273000; val_acc: 0.283000
# (Epoch 8 / 20) train acc: 0.277000; val_acc: 0.302000
# (Iteration 4001 / 9800) loss: 2.021626
# (Epoch 9 / 20) train acc: 0.336000; val_acc: 0.308000
# (Epoch 10 / 20) train acc: 0.303000; val_acc: 0.330000
# (Iteration 5001 / 9800) loss: 2.085473
# (Epoch 11 / 20) train acc: 0.354000; val_acc: 0.347000
# (Epoch 12 / 20) train acc: 0.360000; val_acc: 0.354000
# (Iteration 6001 / 9800) loss: 1.989432
# (Epoch 13 / 20) train acc: 0.344000; val_acc: 0.359000
# (Epoch 14 / 20) train acc: 0.386000; val_acc: 0.369000
# (Iteration 7001 / 9800) loss: 1.961700
# (Epoch 15 / 20) train acc: 0.379000; val_acc: 0.373000
# (Epoch 16 / 20) train acc: 0.413000; val_acc: 0.388000
# (Iteration 8001 / 9800) loss: 2.017004
# (Epoch 17 / 20) train acc: 0.432000; val_acc: 0.389000
# (Epoch 18 / 20) train acc: 0.401000; val_acc: 0.404000
# (Iteration 9001 / 9800) loss: 2.051305
# (Epoch 19 / 20) train acc: 0.413000; val_acc: 0.403000
# (Epoch 20 / 20) train acc: 0.388000; val_acc: 0.416000
# **********************************
# hidden layer dim: 100, lr: 0.0100, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.310912
# (Epoch 0 / 20) train acc: 0.105000; val_acc: 0.093000
# (Epoch 1 / 20) train acc: 0.101000; val_acc: 0.105000
# (Epoch 2 / 20) train acc: 0.094000; val_acc: 0.079000
# (Iteration 1001 / 9800) loss: 2.302033
# (Epoch 3 / 20) train acc: 0.093000; val_acc: 0.087000
# (Epoch 4 / 20) train acc: 0.110000; val_acc: 0.087000
# (Iteration 2001 / 9800) loss: 2.301690
# (Epoch 5 / 20) train acc: 0.093000; val_acc: 0.098000
# (Epoch 6 / 20) train acc: 0.103000; val_acc: 0.087000
# (Iteration 3001 / 9800) loss: 2.302621
# (Epoch 7 / 20) train acc: 0.089000; val_acc: 0.098000
# (Epoch 8 / 20) train acc: 0.104000; val_acc: 0.098000
# (Iteration 4001 / 9800) loss: 2.302331
# (Epoch 9 / 20) train acc: 0.105000; val_acc: 0.079000
# (Epoch 10 / 20) train acc: 0.093000; val_acc: 0.079000
# (Iteration 5001 / 9800) loss: 2.302216
# (Epoch 11 / 20) train acc: 0.105000; val_acc: 0.079000
# (Epoch 12 / 20) train acc: 0.098000; val_acc: 0.079000
# (Iteration 6001 / 9800) loss: 2.302599
# (Epoch 13 / 20) train acc: 0.097000; val_acc: 0.098000
# (Epoch 14 / 20) train acc: 0.098000; val_acc: 0.098000
# (Iteration 7001 / 9800) loss: 2.301857
# (Epoch 15 / 20) train acc: 0.088000; val_acc: 0.098000
# (Epoch 16 / 20) train acc: 0.110000; val_acc: 0.098000
# (Iteration 8001 / 9800) loss: 2.303193
# (Epoch 17 / 20) train acc: 0.109000; val_acc: 0.098000
# (Epoch 18 / 20) train acc: 0.105000; val_acc: 0.098000
# (Iteration 9001 / 9800) loss: 2.302487
# (Epoch 19 / 20) train acc: 0.094000; val_acc: 0.098000
# (Epoch 20 / 20) train acc: 0.102000; val_acc: 0.098000
# **********************************
# hidden layer dim: 100, lr: 0.1000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302583
# (Epoch 0 / 20) train acc: 0.090000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.456000; val_acc: 0.464000
# (Epoch 2 / 20) train acc: 0.534000; val_acc: 0.512000
# (Iteration 1001 / 9800) loss: 1.453777
# (Epoch 3 / 20) train acc: 0.548000; val_acc: 0.527000
# (Epoch 4 / 20) train acc: 0.543000; val_acc: 0.546000
# (Iteration 2001 / 9800) loss: 1.384450
# (Epoch 5 / 20) train acc: 0.566000; val_acc: 0.563000
# (Epoch 6 / 20) train acc: 0.587000; val_acc: 0.563000
# (Iteration 3001 / 9800) loss: 1.236842
# (Epoch 7 / 20) train acc: 0.627000; val_acc: 0.550000
# (Epoch 8 / 20) train acc: 0.624000; val_acc: 0.575000
# (Iteration 4001 / 9800) loss: 1.222257
# (Epoch 9 / 20) train acc: 0.612000; val_acc: 0.568000
# (Epoch 10 / 20) train acc: 0.627000; val_acc: 0.574000
# (Iteration 5001 / 9800) loss: 1.169484
# (Epoch 11 / 20) train acc: 0.613000; val_acc: 0.569000
# (Epoch 12 / 20) train acc: 0.676000; val_acc: 0.568000
# (Iteration 6001 / 9800) loss: 0.972056
# (Epoch 13 / 20) train acc: 0.631000; val_acc: 0.578000
# (Epoch 14 / 20) train acc: 0.635000; val_acc: 0.581000
# (Iteration 7001 / 9800) loss: 0.865754
# (Epoch 15 / 20) train acc: 0.656000; val_acc: 0.590000
# (Epoch 16 / 20) train acc: 0.688000; val_acc: 0.587000
# (Iteration 8001 / 9800) loss: 0.870939
# (Epoch 17 / 20) train acc: 0.650000; val_acc: 0.583000
# (Epoch 18 / 20) train acc: 0.669000; val_acc: 0.580000
# (Iteration 9001 / 9800) loss: 0.880757
# (Epoch 19 / 20) train acc: 0.671000; val_acc: 0.588000
# (Epoch 20 / 20) train acc: 0.685000; val_acc: 0.571000
# **********************************
# hidden layer dim: 100, lr: 0.1000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.302655
# (Epoch 0 / 20) train acc: 0.093000; val_acc: 0.112000
# (Epoch 1 / 20) train acc: 0.440000; val_acc: 0.475000
# (Epoch 2 / 20) train acc: 0.518000; val_acc: 0.502000
# (Iteration 1001 / 9800) loss: 1.546640
# (Epoch 3 / 20) train acc: 0.512000; val_acc: 0.524000
# (Epoch 4 / 20) train acc: 0.509000; val_acc: 0.515000
# (Iteration 2001 / 9800) loss: 1.566970
# (Epoch 5 / 20) train acc: 0.535000; val_acc: 0.519000
# (Epoch 6 / 20) train acc: 0.538000; val_acc: 0.545000
# (Iteration 3001 / 9800) loss: 1.315253
# (Epoch 7 / 20) train acc: 0.525000; val_acc: 0.550000
# (Epoch 8 / 20) train acc: 0.546000; val_acc: 0.532000
# (Iteration 4001 / 9800) loss: 1.355833
# (Epoch 9 / 20) train acc: 0.552000; val_acc: 0.534000
# (Epoch 10 / 20) train acc: 0.598000; val_acc: 0.551000
# (Iteration 5001 / 9800) loss: 1.457292
# (Epoch 11 / 20) train acc: 0.582000; val_acc: 0.540000
# (Epoch 12 / 20) train acc: 0.541000; val_acc: 0.550000
# (Iteration 6001 / 9800) loss: 1.295488
# (Epoch 13 / 20) train acc: 0.554000; val_acc: 0.553000
# (Epoch 14 / 20) train acc: 0.564000; val_acc: 0.548000
# (Iteration 7001 / 9800) loss: 1.276088
# (Epoch 15 / 20) train acc: 0.552000; val_acc: 0.559000
# (Epoch 16 / 20) train acc: 0.563000; val_acc: 0.547000
# (Iteration 8001 / 9800) loss: 1.355586
# (Epoch 17 / 20) train acc: 0.572000; val_acc: 0.537000
# (Epoch 18 / 20) train acc: 0.592000; val_acc: 0.547000
# (Iteration 9001 / 9800) loss: 1.396354
# (Epoch 19 / 20) train acc: 0.529000; val_acc: 0.550000
# (Epoch 20 / 20) train acc: 0.581000; val_acc: 0.560000
# **********************************
# hidden layer dim: 100, lr: 0.1000, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.303411
# (Epoch 0 / 20) train acc: 0.097000; val_acc: 0.098000
# (Epoch 1 / 20) train acc: 0.351000; val_acc: 0.346000
# (Epoch 2 / 20) train acc: 0.432000; val_acc: 0.430000
# (Iteration 1001 / 9800) loss: 1.894820
# (Epoch 3 / 20) train acc: 0.429000; val_acc: 0.441000
# (Epoch 4 / 20) train acc: 0.419000; val_acc: 0.427000
# (Iteration 2001 / 9800) loss: 1.941812
# (Epoch 5 / 20) train acc: 0.451000; val_acc: 0.415000
# (Epoch 6 / 20) train acc: 0.425000; val_acc: 0.411000
# (Iteration 3001 / 9800) loss: 1.893720
# (Epoch 7 / 20) train acc: 0.430000; val_acc: 0.412000
# (Epoch 8 / 20) train acc: 0.447000; val_acc: 0.447000
# (Iteration 4001 / 9800) loss: 2.030994
# (Epoch 9 / 20) train acc: 0.441000; val_acc: 0.423000
# (Epoch 10 / 20) train acc: 0.382000; val_acc: 0.391000
# (Iteration 5001 / 9800) loss: 1.964193
# (Epoch 11 / 20) train acc: 0.419000; val_acc: 0.428000
# (Epoch 12 / 20) train acc: 0.457000; val_acc: 0.430000
# (Iteration 6001 / 9800) loss: 1.955394
# (Epoch 13 / 20) train acc: 0.432000; val_acc: 0.441000
# (Epoch 14 / 20) train acc: 0.441000; val_acc: 0.437000
# (Iteration 7001 / 9800) loss: 2.051997
# (Epoch 15 / 20) train acc: 0.422000; val_acc: 0.441000
# (Epoch 16 / 20) train acc: 0.433000; val_acc: 0.445000
# (Iteration 8001 / 9800) loss: 1.877029
# (Epoch 17 / 20) train acc: 0.449000; val_acc: 0.441000
# (Epoch 18 / 20) train acc: 0.435000; val_acc: 0.435000
# (Iteration 9001 / 9800) loss: 2.049679
# (Epoch 19 / 20) train acc: 0.455000; val_acc: 0.412000
# (Epoch 20 / 20) train acc: 0.438000; val_acc: 0.428000
# **********************************
# hidden layer dim: 100, lr: 0.1000, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.310724
# (Epoch 0 / 20) train acc: 0.108000; val_acc: 0.131000
# (Epoch 1 / 20) train acc: 0.113000; val_acc: 0.098000
# (Epoch 2 / 20) train acc: 0.093000; val_acc: 0.078000
# (Iteration 1001 / 9800) loss: 2.298140
# (Epoch 3 / 20) train acc: 0.100000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.093000; val_acc: 0.119000
# (Iteration 2001 / 9800) loss: 2.302096
# (Epoch 5 / 20) train acc: 0.097000; val_acc: 0.113000
# (Epoch 6 / 20) train acc: 0.105000; val_acc: 0.119000
# (Iteration 3001 / 9800) loss: 2.300864
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.105000
# (Epoch 8 / 20) train acc: 0.112000; val_acc: 0.079000
# (Iteration 4001 / 9800) loss: 2.303362
# (Epoch 9 / 20) train acc: 0.100000; val_acc: 0.113000
# (Epoch 10 / 20) train acc: 0.119000; val_acc: 0.105000
# (Iteration 5001 / 9800) loss: 2.303801
# (Epoch 11 / 20) train acc: 0.107000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.082000; val_acc: 0.113000
# (Iteration 6001 / 9800) loss: 2.303728
# (Epoch 13 / 20) train acc: 0.111000; val_acc: 0.105000
# (Epoch 14 / 20) train acc: 0.104000; val_acc: 0.079000
# (Iteration 7001 / 9800) loss: 2.298331
# (Epoch 15 / 20) train acc: 0.100000; val_acc: 0.102000
# (Epoch 16 / 20) train acc: 0.110000; val_acc: 0.079000
# (Iteration 8001 / 9800) loss: 2.301240
# (Epoch 17 / 20) train acc: 0.100000; val_acc: 0.112000
# (Epoch 18 / 20) train acc: 0.090000; val_acc: 0.098000
# (Iteration 9001 / 9800) loss: 2.303652
# (Epoch 19 / 20) train acc: 0.098000; val_acc: 0.112000
# (Epoch 20 / 20) train acc: 0.091000; val_acc: 0.105000
# **********************************
# hidden layer dim: 100, lr: 1.0000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302591
# (Epoch 0 / 20) train acc: 0.115000; val_acc: 0.078000
# (Epoch 1 / 20) train acc: 0.511000; val_acc: 0.507000
# (Epoch 2 / 20) train acc: 0.500000; val_acc: 0.487000
# (Iteration 1001 / 9800) loss: 1.557860
# (Epoch 3 / 20) train acc: 0.576000; val_acc: 0.534000
# (Epoch 4 / 20) train acc: 0.563000; val_acc: 0.534000
# (Iteration 2001 / 9800) loss: 1.044362
# (Epoch 5 / 20) train acc: 0.604000; val_acc: 0.531000
# (Epoch 6 / 20) train acc: 0.618000; val_acc: 0.533000
# (Iteration 3001 / 9800) loss: 1.092183
# (Epoch 7 / 20) train acc: 0.643000; val_acc: 0.549000
# (Epoch 8 / 20) train acc: 0.648000; val_acc: 0.528000
# (Iteration 4001 / 9800) loss: 1.206891
# (Epoch 9 / 20) train acc: 0.632000; val_acc: 0.522000
# (Epoch 10 / 20) train acc: 0.655000; val_acc: 0.542000
# (Iteration 5001 / 9800) loss: 0.912251
# (Epoch 11 / 20) train acc: 0.634000; val_acc: 0.544000
# (Epoch 12 / 20) train acc: 0.670000; val_acc: 0.542000
# (Iteration 6001 / 9800) loss: 1.095943
# (Epoch 13 / 20) train acc: 0.706000; val_acc: 0.537000
# (Epoch 14 / 20) train acc: 0.646000; val_acc: 0.548000
# (Iteration 7001 / 9800) loss: 1.120590
# (Epoch 15 / 20) train acc: 0.691000; val_acc: 0.542000
# (Epoch 16 / 20) train acc: 0.664000; val_acc: 0.533000
# (Iteration 8001 / 9800) loss: 0.727093
# (Epoch 17 / 20) train acc: 0.696000; val_acc: 0.523000
# (Epoch 18 / 20) train acc: 0.678000; val_acc: 0.544000
# (Iteration 9001 / 9800) loss: 0.895351
# (Epoch 19 / 20) train acc: 0.667000; val_acc: 0.536000
# (Epoch 20 / 20) train acc: 0.700000; val_acc: 0.550000
# **********************************
# hidden layer dim: 100, lr: 1.0000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.302647
# (Epoch 0 / 20) train acc: 0.106000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.457000; val_acc: 0.468000
# (Epoch 2 / 20) train acc: 0.467000; val_acc: 0.493000
# (Iteration 1001 / 9800) loss: 1.701126
# (Epoch 3 / 20) train acc: 0.531000; val_acc: 0.478000
# (Epoch 4 / 20) train acc: 0.506000; val_acc: 0.505000
# (Iteration 2001 / 9800) loss: 1.633054
# (Epoch 5 / 20) train acc: 0.509000; val_acc: 0.471000
# (Epoch 6 / 20) train acc: 0.508000; val_acc: 0.515000
# (Iteration 3001 / 9800) loss: 1.646794
# (Epoch 7 / 20) train acc: 0.496000; val_acc: 0.489000
# (Epoch 8 / 20) train acc: 0.468000; val_acc: 0.486000
# (Iteration 4001 / 9800) loss: 1.558413
# (Epoch 9 / 20) train acc: 0.489000; val_acc: 0.489000
# (Epoch 10 / 20) train acc: 0.533000; val_acc: 0.474000
# (Iteration 5001 / 9800) loss: 1.571731
# (Epoch 11 / 20) train acc: 0.492000; val_acc: 0.481000
# (Epoch 12 / 20) train acc: 0.518000; val_acc: 0.516000
# (Iteration 6001 / 9800) loss: 1.618385
# (Epoch 13 / 20) train acc: 0.517000; val_acc: 0.509000
# (Epoch 14 / 20) train acc: 0.519000; val_acc: 0.496000
# (Iteration 7001 / 9800) loss: 1.526663
# (Epoch 15 / 20) train acc: 0.564000; val_acc: 0.524000
# (Epoch 16 / 20) train acc: 0.522000; val_acc: 0.500000
# (Iteration 8001 / 9800) loss: 1.676422
# (Epoch 17 / 20) train acc: 0.540000; val_acc: 0.527000
# (Epoch 18 / 20) train acc: 0.529000; val_acc: 0.513000
# (Iteration 9001 / 9800) loss: 1.469302
# (Epoch 19 / 20) train acc: 0.587000; val_acc: 0.523000
# (Epoch 20 / 20) train acc: 0.538000; val_acc: 0.541000
# **********************************
# hidden layer dim: 100, lr: 1.0000, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.303389
# (Epoch 0 / 20) train acc: 0.095000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.325000; val_acc: 0.313000
# (Epoch 2 / 20) train acc: 0.331000; val_acc: 0.384000
# (Iteration 1001 / 9800) loss: 2.026933
# (Epoch 3 / 20) train acc: 0.395000; val_acc: 0.385000
# (Epoch 4 / 20) train acc: 0.364000; val_acc: 0.362000
# (Iteration 2001 / 9800) loss: 2.110596
# (Epoch 5 / 20) train acc: 0.318000; val_acc: 0.341000
# (Epoch 6 / 20) train acc: 0.335000; val_acc: 0.293000
# (Iteration 3001 / 9800) loss: 1.912283
# (Epoch 7 / 20) train acc: 0.373000; val_acc: 0.354000
# (Epoch 8 / 20) train acc: 0.322000; val_acc: 0.297000
# (Iteration 4001 / 9800) loss: 2.037416
# (Epoch 9 / 20) train acc: 0.405000; val_acc: 0.351000
# (Epoch 10 / 20) train acc: 0.334000; val_acc: 0.341000
# (Iteration 5001 / 9800) loss: 2.299198
# (Epoch 11 / 20) train acc: 0.368000; val_acc: 0.371000
# (Epoch 12 / 20) train acc: 0.400000; val_acc: 0.395000
# (Iteration 6001 / 9800) loss: 1.980600
# (Epoch 13 / 20) train acc: 0.367000; val_acc: 0.367000
# (Epoch 14 / 20) train acc: 0.343000; val_acc: 0.344000
# (Iteration 7001 / 9800) loss: 1.878062
# (Epoch 15 / 20) train acc: 0.422000; val_acc: 0.389000
# (Epoch 16 / 20) train acc: 0.365000; val_acc: 0.374000
# (Iteration 8001 / 9800) loss: 1.914009
# (Epoch 17 / 20) train acc: 0.333000; val_acc: 0.360000
# (Epoch 18 / 20) train acc: 0.421000; val_acc: 0.415000
# (Iteration 9001 / 9800) loss: 2.037921
# (Epoch 19 / 20) train acc: 0.410000; val_acc: 0.349000
# (Epoch 20 / 20) train acc: 0.404000; val_acc: 0.378000
# **********************************
# hidden layer dim: 100, lr: 1.0000, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.310908
# (Epoch 0 / 20) train acc: 0.099000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.103000; val_acc: 0.107000
# (Epoch 2 / 20) train acc: 0.099000; val_acc: 0.079000
# (Iteration 1001 / 9800) loss: 2.312562
# (Epoch 3 / 20) train acc: 0.102000; val_acc: 0.112000
# (Epoch 4 / 20) train acc: 0.097000; val_acc: 0.107000
# (Iteration 2001 / 9800) loss: 2.296928
# (Epoch 5 / 20) train acc: 0.097000; val_acc: 0.119000
# (Epoch 6 / 20) train acc: 0.106000; val_acc: 0.098000
# (Iteration 3001 / 9800) loss: 2.290367
# (Epoch 7 / 20) train acc: 0.094000; val_acc: 0.112000
# (Epoch 8 / 20) train acc: 0.097000; val_acc: 0.107000
# (Iteration 4001 / 9800) loss: 2.305944
# (Epoch 9 / 20) train acc: 0.110000; val_acc: 0.079000
# (Epoch 10 / 20) train acc: 0.079000; val_acc: 0.098000
# (Iteration 5001 / 9800) loss: 2.300650
# (Epoch 11 / 20) train acc: 0.090000; val_acc: 0.087000
# (Epoch 12 / 20) train acc: 0.105000; val_acc: 0.079000
# (Iteration 6001 / 9800) loss: 2.307453
# (Epoch 13 / 20) train acc: 0.095000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.111000; val_acc: 0.112000
# (Iteration 7001 / 9800) loss: 2.302800
# (Epoch 15 / 20) train acc: 0.098000; val_acc: 0.079000
# (Epoch 16 / 20) train acc: 0.109000; val_acc: 0.087000
# (Iteration 8001 / 9800) loss: 2.306043
# (Epoch 17 / 20) train acc: 0.094000; val_acc: 0.107000
# (Epoch 18 / 20) train acc: 0.101000; val_acc: 0.087000
# (Iteration 9001 / 9800) loss: 2.306951
# (Epoch 19 / 20) train acc: 0.092000; val_acc: 0.105000
# (Epoch 20 / 20) train acc: 0.107000; val_acc: 0.119000
# **********************************
# hidden layer dim: 500, lr: 0.0100, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302588
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.077000
# (Epoch 1 / 20) train acc: 0.115000; val_acc: 0.116000
# (Epoch 2 / 20) train acc: 0.276000; val_acc: 0.270000
# (Iteration 1001 / 9800) loss: 2.259490
# (Epoch 3 / 20) train acc: 0.250000; val_acc: 0.305000
# (Epoch 4 / 20) train acc: 0.355000; val_acc: 0.348000
# (Iteration 2001 / 9800) loss: 1.824184
# (Epoch 5 / 20) train acc: 0.401000; val_acc: 0.396000
# (Epoch 6 / 20) train acc: 0.411000; val_acc: 0.410000
# (Iteration 3001 / 9800) loss: 1.557929
# (Epoch 7 / 20) train acc: 0.434000; val_acc: 0.435000
# (Epoch 8 / 20) train acc: 0.492000; val_acc: 0.437000
# (Iteration 4001 / 9800) loss: 1.506652
# (Epoch 9 / 20) train acc: 0.439000; val_acc: 0.461000
# (Epoch 10 / 20) train acc: 0.515000; val_acc: 0.470000
# (Iteration 5001 / 9800) loss: 1.502189
# (Epoch 11 / 20) train acc: 0.499000; val_acc: 0.485000
# (Epoch 12 / 20) train acc: 0.515000; val_acc: 0.488000
# (Iteration 6001 / 9800) loss: 1.609838
# (Epoch 13 / 20) train acc: 0.527000; val_acc: 0.492000
# (Epoch 14 / 20) train acc: 0.506000; val_acc: 0.500000
# (Iteration 7001 / 9800) loss: 1.017829
# (Epoch 15 / 20) train acc: 0.514000; val_acc: 0.506000
# (Epoch 16 / 20) train acc: 0.509000; val_acc: 0.507000
# (Iteration 8001 / 9800) loss: 1.392985
# (Epoch 17 / 20) train acc: 0.531000; val_acc: 0.510000
# (Epoch 18 / 20) train acc: 0.516000; val_acc: 0.510000
# (Iteration 9001 / 9800) loss: 1.283073
# (Epoch 19 / 20) train acc: 0.522000; val_acc: 0.511000
# (Epoch 20 / 20) train acc: 0.544000; val_acc: 0.518000
# **********************************
# hidden layer dim: 500, lr: 0.0100, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.303012
# (Epoch 0 / 20) train acc: 0.119000; val_acc: 0.099000
# (Epoch 1 / 20) train acc: 0.233000; val_acc: 0.226000
# (Epoch 2 / 20) train acc: 0.235000; val_acc: 0.233000
# (Iteration 1001 / 9800) loss: 2.250242
# (Epoch 3 / 20) train acc: 0.283000; val_acc: 0.281000
# (Epoch 4 / 20) train acc: 0.320000; val_acc: 0.333000
# (Iteration 2001 / 9800) loss: 1.894660
# (Epoch 5 / 20) train acc: 0.395000; val_acc: 0.387000
# (Epoch 6 / 20) train acc: 0.411000; val_acc: 0.407000
# (Iteration 3001 / 9800) loss: 1.634077
# (Epoch 7 / 20) train acc: 0.429000; val_acc: 0.420000
# (Epoch 8 / 20) train acc: 0.408000; val_acc: 0.444000
# (Iteration 4001 / 9800) loss: 1.535366
# (Epoch 9 / 20) train acc: 0.487000; val_acc: 0.452000
# (Epoch 10 / 20) train acc: 0.472000; val_acc: 0.469000
# (Iteration 5001 / 9800) loss: 1.430541
# (Epoch 11 / 20) train acc: 0.488000; val_acc: 0.480000
# (Epoch 12 / 20) train acc: 0.493000; val_acc: 0.477000
# (Iteration 6001 / 9800) loss: 1.580887
# (Epoch 13 / 20) train acc: 0.494000; val_acc: 0.483000
# (Epoch 14 / 20) train acc: 0.499000; val_acc: 0.491000
# (Iteration 7001 / 9800) loss: 1.557377
# (Epoch 15 / 20) train acc: 0.511000; val_acc: 0.498000
# (Epoch 16 / 20) train acc: 0.521000; val_acc: 0.501000
# (Iteration 8001 / 9800) loss: 1.532176
# (Epoch 17 / 20) train acc: 0.543000; val_acc: 0.502000
# (Epoch 18 / 20) train acc: 0.514000; val_acc: 0.503000
# (Iteration 9001 / 9800) loss: 1.637678
# (Epoch 19 / 20) train acc: 0.516000; val_acc: 0.508000
# (Epoch 20 / 20) train acc: 0.504000; val_acc: 0.507000
# **********************************
# hidden layer dim: 500, lr: 0.0100, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.306662
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.154000; val_acc: 0.178000
# (Epoch 2 / 20) train acc: 0.176000; val_acc: 0.183000
# (Iteration 1001 / 9800) loss: 2.293205
# (Epoch 3 / 20) train acc: 0.200000; val_acc: 0.212000
# (Epoch 4 / 20) train acc: 0.242000; val_acc: 0.243000
# (Iteration 2001 / 9800) loss: 2.102250
# (Epoch 5 / 20) train acc: 0.251000; val_acc: 0.283000
# (Epoch 6 / 20) train acc: 0.270000; val_acc: 0.287000
# (Iteration 3001 / 9800) loss: 2.139904
# (Epoch 7 / 20) train acc: 0.303000; val_acc: 0.310000
# (Epoch 8 / 20) train acc: 0.325000; val_acc: 0.330000
# (Iteration 4001 / 9800) loss: 2.055616
# (Epoch 9 / 20) train acc: 0.347000; val_acc: 0.353000
# (Epoch 10 / 20) train acc: 0.398000; val_acc: 0.371000
# (Iteration 5001 / 9800) loss: 2.020243
# (Epoch 11 / 20) train acc: 0.377000; val_acc: 0.383000
# (Epoch 12 / 20) train acc: 0.413000; val_acc: 0.400000
# (Iteration 6001 / 9800) loss: 2.070018
# (Epoch 13 / 20) train acc: 0.401000; val_acc: 0.399000
# (Epoch 14 / 20) train acc: 0.424000; val_acc: 0.407000
# (Iteration 7001 / 9800) loss: 2.011793
# (Epoch 15 / 20) train acc: 0.413000; val_acc: 0.400000
# (Epoch 16 / 20) train acc: 0.421000; val_acc: 0.407000
# (Iteration 8001 / 9800) loss: 1.980242
# (Epoch 17 / 20) train acc: 0.401000; val_acc: 0.407000
# (Epoch 18 / 20) train acc: 0.419000; val_acc: 0.401000
# (Iteration 9001 / 9800) loss: 2.005052
# (Epoch 19 / 20) train acc: 0.405000; val_acc: 0.410000
# (Epoch 20 / 20) train acc: 0.411000; val_acc: 0.411000
# **********************************
# hidden layer dim: 500, lr: 0.0100, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.343373
# (Epoch 0 / 20) train acc: 0.111000; val_acc: 0.080000
# (Epoch 1 / 20) train acc: 0.101000; val_acc: 0.098000
# (Epoch 2 / 20) train acc: 0.097000; val_acc: 0.098000
# (Iteration 1001 / 9800) loss: 2.303115
# (Epoch 3 / 20) train acc: 0.086000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.113000; val_acc: 0.078000
# (Iteration 2001 / 9800) loss: 2.303389
# (Epoch 5 / 20) train acc: 0.089000; val_acc: 0.078000
# (Epoch 6 / 20) train acc: 0.103000; val_acc: 0.105000
# (Iteration 3001 / 9800) loss: 2.302955
# (Epoch 7 / 20) train acc: 0.100000; val_acc: 0.079000
# (Epoch 8 / 20) train acc: 0.112000; val_acc: 0.098000
# (Iteration 4001 / 9800) loss: 2.303127
# (Epoch 9 / 20) train acc: 0.097000; val_acc: 0.119000
# (Epoch 10 / 20) train acc: 0.089000; val_acc: 0.105000
# (Iteration 5001 / 9800) loss: 2.302258
# (Epoch 11 / 20) train acc: 0.109000; val_acc: 0.105000
# (Epoch 12 / 20) train acc: 0.112000; val_acc: 0.105000
# (Iteration 6001 / 9800) loss: 2.303163
# (Epoch 13 / 20) train acc: 0.092000; val_acc: 0.078000
# (Epoch 14 / 20) train acc: 0.097000; val_acc: 0.105000
# (Iteration 7001 / 9800) loss: 2.302189
# (Epoch 15 / 20) train acc: 0.081000; val_acc: 0.078000
# (Epoch 16 / 20) train acc: 0.097000; val_acc: 0.078000
# (Iteration 8001 / 9800) loss: 2.303099
# (Epoch 17 / 20) train acc: 0.106000; val_acc: 0.078000
# (Epoch 18 / 20) train acc: 0.088000; val_acc: 0.078000
# (Iteration 9001 / 9800) loss: 2.301882
# (Epoch 19 / 20) train acc: 0.098000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.099000; val_acc: 0.078000
# **********************************
# hidden layer dim: 500, lr: 0.1000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302610
# (Epoch 0 / 20) train acc: 0.094000; val_acc: 0.105000
# (Epoch 1 / 20) train acc: 0.501000; val_acc: 0.489000
# (Epoch 2 / 20) train acc: 0.519000; val_acc: 0.506000
# (Iteration 1001 / 9800) loss: 1.173051
# (Epoch 3 / 20) train acc: 0.545000; val_acc: 0.539000
# (Epoch 4 / 20) train acc: 0.581000; val_acc: 0.549000
# (Iteration 2001 / 9800) loss: 1.139182
# (Epoch 5 / 20) train acc: 0.577000; val_acc: 0.557000
# (Epoch 6 / 20) train acc: 0.628000; val_acc: 0.588000
# (Iteration 3001 / 9800) loss: 1.111038
# (Epoch 7 / 20) train acc: 0.637000; val_acc: 0.589000
# (Epoch 8 / 20) train acc: 0.633000; val_acc: 0.591000
# (Iteration 4001 / 9800) loss: 1.139163
# (Epoch 9 / 20) train acc: 0.665000; val_acc: 0.594000
# (Epoch 10 / 20) train acc: 0.649000; val_acc: 0.598000
# (Iteration 5001 / 9800) loss: 0.981585
# (Epoch 11 / 20) train acc: 0.691000; val_acc: 0.606000
# (Epoch 12 / 20) train acc: 0.702000; val_acc: 0.597000
# (Iteration 6001 / 9800) loss: 1.047117
# (Epoch 13 / 20) train acc: 0.715000; val_acc: 0.596000
# (Epoch 14 / 20) train acc: 0.689000; val_acc: 0.591000
# (Iteration 7001 / 9800) loss: 0.912398
# (Epoch 15 / 20) train acc: 0.709000; val_acc: 0.589000
# (Epoch 16 / 20) train acc: 0.734000; val_acc: 0.590000
# (Iteration 8001 / 9800) loss: 0.869308
# (Epoch 17 / 20) train acc: 0.758000; val_acc: 0.597000
# (Epoch 18 / 20) train acc: 0.722000; val_acc: 0.592000
# (Iteration 9001 / 9800) loss: 0.631983
# (Epoch 19 / 20) train acc: 0.752000; val_acc: 0.589000
# (Epoch 20 / 20) train acc: 0.757000; val_acc: 0.593000
# **********************************
# hidden layer dim: 500, lr: 0.1000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.303027
# (Epoch 0 / 20) train acc: 0.095000; val_acc: 0.078000
# (Epoch 1 / 20) train acc: 0.476000; val_acc: 0.493000
# (Epoch 2 / 20) train acc: 0.521000; val_acc: 0.512000
# (Iteration 1001 / 9800) loss: 1.579817
# (Epoch 3 / 20) train acc: 0.523000; val_acc: 0.521000
# (Epoch 4 / 20) train acc: 0.557000; val_acc: 0.523000
# (Iteration 2001 / 9800) loss: 1.348600
# (Epoch 5 / 20) train acc: 0.547000; val_acc: 0.536000
# (Epoch 6 / 20) train acc: 0.526000; val_acc: 0.535000
# (Iteration 3001 / 9800) loss: 1.373492
# (Epoch 7 / 20) train acc: 0.597000; val_acc: 0.541000
# (Epoch 8 / 20) train acc: 0.603000; val_acc: 0.540000
# (Iteration 4001 / 9800) loss: 1.548576
# (Epoch 9 / 20) train acc: 0.566000; val_acc: 0.544000
# (Epoch 10 / 20) train acc: 0.575000; val_acc: 0.542000
# (Iteration 5001 / 9800) loss: 1.451402
# (Epoch 11 / 20) train acc: 0.591000; val_acc: 0.555000
# (Epoch 12 / 20) train acc: 0.571000; val_acc: 0.572000
# (Iteration 6001 / 9800) loss: 1.435134
# (Epoch 13 / 20) train acc: 0.574000; val_acc: 0.551000
# (Epoch 14 / 20) train acc: 0.556000; val_acc: 0.557000
# (Iteration 7001 / 9800) loss: 1.211083
# ...
# (Epoch 2 / 20) train acc: 0.221000; val_acc: 0.222000
# (Iteration 1001 / 9800) loss: 2.291511
# (Epoch 3 / 20) train acc: 0.210000; val_acc: 0.231000
# (Epoch 4 / 20) train acc: 0.285000; val_acc: 0.286000
# (Iteration 2001 / 9800) loss: 2.194694
# (Epoch 5 / 20) train acc: 0.274000; val_acc: 0.289000
# (Epoch 6 / 20) train acc: 0.321000; val_acc: 0.311000
# (Iteration 3001 / 9800) loss: 2.061814
# (Epoch 7 / 20) train acc: 0.323000; val_acc: 0.331000
# (Epoch 8 / 20) train acc: 0.339000; val_acc: 0.351000
# (Iteration 4001 / 9800) loss: 2.002211
# (Epoch 9 / 20) train acc: 0.396000; val_acc: 0.372000
# (Epoch 10 / 20) train acc: 0.392000; val_acc: 0.371000
# (Iteration 5001 / 9800) loss: 2.013067
# (Epoch 11 / 20) train acc: 0.365000; val_acc: 0.383000
# (Epoch 12 / 20) train acc: 0.384000; val_acc: 0.405000
# (Iteration 6001 / 9800) loss: 1.982812
# (Epoch 13 / 20) train acc: 0.390000; val_acc: 0.410000
# (Epoch 14 / 20) train acc: 0.406000; val_acc: 0.406000
# (Iteration 7001 / 9800) loss: 1.959510
# (Epoch 15 / 20) train acc: 0.413000; val_acc: 0.403000
# (Epoch 16 / 20) train acc: 0.400000; val_acc: 0.410000
# (Iteration 8001 / 9800) loss: 2.053241
# (Epoch 17 / 20) train acc: 0.440000; val_acc: 0.415000
# (Epoch 18 / 20) train acc: 0.433000; val_acc: 0.413000
# (Iteration 9001 / 9800) loss: 2.001083
# (Epoch 19 / 20) train acc: 0.418000; val_acc: 0.418000
# (Epoch 20 / 20) train acc: 0.428000; val_acc: 0.417000
# **********************************
# hidden layer dim: 1000, lr: 0.0100, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.384481
# (Epoch 0 / 20) train acc: 0.120000; val_acc: 0.117000
# (Epoch 1 / 20) train acc: 0.095000; val_acc: 0.113000
# (Epoch 2 / 20) train acc: 0.115000; val_acc: 0.112000
# (Iteration 1001 / 9800) loss: 2.301532
# (Epoch 3 / 20) train acc: 0.108000; val_acc: 0.079000
# (Epoch 4 / 20) train acc: 0.108000; val_acc: 0.079000
# (Iteration 2001 / 9800) loss: 2.301655
# (Epoch 5 / 20) train acc: 0.093000; val_acc: 0.079000
# (Epoch 6 / 20) train acc: 0.098000; val_acc: 0.078000
# (Iteration 3001 / 9800) loss: 2.302017
# (Epoch 7 / 20) train acc: 0.091000; val_acc: 0.079000
# (Epoch 8 / 20) train acc: 0.095000; val_acc: 0.078000
# (Iteration 4001 / 9800) loss: 2.302777
# (Epoch 9 / 20) train acc: 0.107000; val_acc: 0.078000
# (Epoch 10 / 20) train acc: 0.101000; val_acc: 0.078000
# (Iteration 5001 / 9800) loss: 2.302400
# (Epoch 11 / 20) train acc: 0.106000; val_acc: 0.105000
# (Epoch 12 / 20) train acc: 0.112000; val_acc: 0.087000
# (Iteration 6001 / 9800) loss: 2.301244
# (Epoch 13 / 20) train acc: 0.103000; val_acc: 0.087000
# (Epoch 14 / 20) train acc: 0.092000; val_acc: 0.105000
# (Iteration 7001 / 9800) loss: 2.302603
# (Epoch 15 / 20) train acc: 0.093000; val_acc: 0.105000
# (Epoch 16 / 20) train acc: 0.100000; val_acc: 0.107000
# (Iteration 8001 / 9800) loss: 2.303215
# (Epoch 17 / 20) train acc: 0.083000; val_acc: 0.079000
# (Epoch 18 / 20) train acc: 0.099000; val_acc: 0.079000
# (Iteration 9001 / 9800) loss: 2.302032
# (Epoch 19 / 20) train acc: 0.124000; val_acc: 0.087000
# (Epoch 20 / 20) train acc: 0.088000; val_acc: 0.107000
# **********************************
# hidden layer dim: 1000, lr: 0.1000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302572
# (Epoch 0 / 20) train acc: 0.100000; val_acc: 0.114000
# (Epoch 1 / 20) train acc: 0.496000; val_acc: 0.501000
# (Epoch 2 / 20) train acc: 0.527000; val_acc: 0.520000
# (Iteration 1001 / 9800) loss: 1.147894
# (Epoch 3 / 20) train acc: 0.536000; val_acc: 0.528000
# (Epoch 4 / 20) train acc: 0.587000; val_acc: 0.572000
# (Iteration 2001 / 9800) loss: 1.136270
# (Epoch 5 / 20) train acc: 0.612000; val_acc: 0.586000
# (Epoch 6 / 20) train acc: 0.612000; val_acc: 0.577000
# (Iteration 3001 / 9800) loss: 1.090178
# (Epoch 7 / 20) train acc: 0.627000; val_acc: 0.579000
# (Epoch 8 / 20) train acc: 0.656000; val_acc: 0.588000
# (Iteration 4001 / 9800) loss: 1.050852
# (Epoch 9 / 20) train acc: 0.684000; val_acc: 0.590000
# (Epoch 10 / 20) train acc: 0.677000; val_acc: 0.602000
# (Iteration 5001 / 9800) loss: 0.886480
# (Epoch 11 / 20) train acc: 0.661000; val_acc: 0.606000
# (Epoch 12 / 20) train acc: 0.711000; val_acc: 0.597000
# (Iteration 6001 / 9800) loss: 0.853529
# (Epoch 13 / 20) train acc: 0.722000; val_acc: 0.604000
# (Epoch 14 / 20) train acc: 0.728000; val_acc: 0.601000
# (Iteration 7001 / 9800) loss: 0.733087
# (Epoch 15 / 20) train acc: 0.739000; val_acc: 0.605000
# (Epoch 16 / 20) train acc: 0.756000; val_acc: 0.627000
# (Iteration 8001 / 9800) loss: 0.635214
# (Epoch 17 / 20) train acc: 0.736000; val_acc: 0.606000
# (Epoch 18 / 20) train acc: 0.777000; val_acc: 0.601000
# (Iteration 9001 / 9800) loss: 0.599311
# (Epoch 19 / 20) train acc: 0.778000; val_acc: 0.610000
# (Epoch 20 / 20) train acc: 0.807000; val_acc: 0.609000
# **********************************
# hidden layer dim: 1000, lr: 0.1000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.303402
# (Epoch 0 / 20) train acc: 0.093000; val_acc: 0.079000
# (Epoch 1 / 20) train acc: 0.522000; val_acc: 0.499000
# (Epoch 2 / 20) train acc: 0.524000; val_acc: 0.506000
# (Iteration 1001 / 9800) loss: 1.438054
# (Epoch 3 / 20) train acc: 0.523000; val_acc: 0.522000
# (Epoch 4 / 20) train acc: 0.536000; val_acc: 0.529000
# (Iteration 2001 / 9800) loss: 1.439098
# (Epoch 5 / 20) train acc: 0.549000; val_acc: 0.523000
# (Epoch 6 / 20) train acc: 0.564000; val_acc: 0.545000
# (Iteration 3001 / 9800) loss: 1.289520
# (Epoch 7 / 20) train acc: 0.577000; val_acc: 0.549000
# (Epoch 8 / 20) train acc: 0.555000; val_acc: 0.555000
# (Iteration 4001 / 9800) loss: 1.522579
# (Epoch 9 / 20) train acc: 0.580000; val_acc: 0.543000
# (Epoch 10 / 20) train acc: 0.589000; val_acc: 0.551000
# (Iteration 5001 / 9800) loss: 1.454664
# (Epoch 11 / 20) train acc: 0.593000; val_acc: 0.567000
# (Epoch 12 / 20) train acc: 0.579000; val_acc: 0.557000
# (Iteration 6001 / 9800) loss: 1.352759
# (Epoch 13 / 20) train acc: 0.578000; val_acc: 0.559000
# (Epoch 14 / 20) train acc: 0.584000; val_acc: 0.557000
# (Iteration 7001 / 9800) loss: 1.387325
# (Epoch 15 / 20) train acc: 0.603000; val_acc: 0.572000
# (Epoch 16 / 20) train acc: 0.577000; val_acc: 0.548000
# (Iteration 8001 / 9800) loss: 1.470242
# (Epoch 17 / 20) train acc: 0.574000; val_acc: 0.570000
# (Epoch 18 / 20) train acc: 0.578000; val_acc: 0.575000
# (Iteration 9001 / 9800) loss: 1.404671
# (Epoch 19 / 20) train acc: 0.583000; val_acc: 0.569000
# (Epoch 20 / 20) train acc: 0.580000; val_acc: 0.572000
# **********************************
# hidden layer dim: 1000, lr: 0.1000, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.310804
# (Epoch 0 / 20) train acc: 0.086000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.420000; val_acc: 0.384000
# (Epoch 2 / 20) train acc: 0.431000; val_acc: 0.442000
# (Iteration 1001 / 9800) loss: 1.872738
# (Epoch 3 / 20) train acc: 0.444000; val_acc: 0.428000
# (Epoch 4 / 20) train acc: 0.444000; val_acc: 0.448000
# (Iteration 2001 / 9800) loss: 1.989460
# (Epoch 5 / 20) train acc: 0.426000; val_acc: 0.446000
# (Epoch 6 / 20) train acc: 0.417000; val_acc: 0.442000
# (Iteration 3001 / 9800) loss: 1.913741
# (Epoch 7 / 20) train acc: 0.438000; val_acc: 0.420000
# (Epoch 8 / 20) train acc: 0.433000; val_acc: 0.433000
# (Iteration 4001 / 9800) loss: 2.004278
# (Epoch 9 / 20) train acc: 0.405000; val_acc: 0.446000
# (Epoch 10 / 20) train acc: 0.453000; val_acc: 0.442000
# (Iteration 5001 / 9800) loss: 1.927407
# (Epoch 11 / 20) train acc: 0.429000; val_acc: 0.439000
# (Epoch 12 / 20) train acc: 0.456000; val_acc: 0.441000
# (Iteration 6001 / 9800) loss: 1.903385
# (Epoch 13 / 20) train acc: 0.412000; val_acc: 0.436000
# (Epoch 14 / 20) train acc: 0.459000; val_acc: 0.411000
# (Iteration 7001 / 9800) loss: 1.891109
# (Epoch 15 / 20) train acc: 0.447000; val_acc: 0.420000
# (Epoch 16 / 20) train acc: 0.475000; val_acc: 0.442000
# (Iteration 8001 / 9800) loss: 1.818702
# (Epoch 17 / 20) train acc: 0.446000; val_acc: 0.419000
# (Epoch 18 / 20) train acc: 0.460000; val_acc: 0.417000
# (Iteration 9001 / 9800) loss: 1.946849
# (Epoch 19 / 20) train acc: 0.466000; val_acc: 0.441000
# (Epoch 20 / 20) train acc: 0.440000; val_acc: 0.421000
# **********************************
# hidden layer dim: 1000, lr: 0.1000, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.384652
# (Epoch 0 / 20) train acc: 0.104000; val_acc: 0.105000
# (Epoch 1 / 20) train acc: 0.105000; val_acc: 0.079000
# (Epoch 2 / 20) train acc: 0.103000; val_acc: 0.113000
# (Iteration 1001 / 9800) loss: 2.305219
# (Epoch 3 / 20) train acc: 0.109000; val_acc: 0.107000
# (Epoch 4 / 20) train acc: 0.092000; val_acc: 0.098000
# (Iteration 2001 / 9800) loss: 2.303971
# (Epoch 5 / 20) train acc: 0.091000; val_acc: 0.078000
# (Epoch 6 / 20) train acc: 0.105000; val_acc: 0.078000
# (Iteration 3001 / 9800) loss: 2.303763
# (Epoch 7 / 20) train acc: 0.093000; val_acc: 0.078000
# (Epoch 8 / 20) train acc: 0.096000; val_acc: 0.105000
# (Iteration 4001 / 9800) loss: 2.303718
# (Epoch 9 / 20) train acc: 0.086000; val_acc: 0.113000
# (Epoch 10 / 20) train acc: 0.104000; val_acc: 0.087000
# (Iteration 5001 / 9800) loss: 2.304082
# (Epoch 11 / 20) train acc: 0.095000; val_acc: 0.107000
# (Epoch 12 / 20) train acc: 0.102000; val_acc: 0.102000
# (Iteration 6001 / 9800) loss: 2.300339
# (Epoch 13 / 20) train acc: 0.087000; val_acc: 0.079000
# (Epoch 14 / 20) train acc: 0.105000; val_acc: 0.102000
# (Iteration 7001 / 9800) loss: 2.305441
# (Epoch 15 / 20) train acc: 0.089000; val_acc: 0.113000
# (Epoch 16 / 20) train acc: 0.114000; val_acc: 0.112000
# (Iteration 8001 / 9800) loss: 2.303479
# (Epoch 17 / 20) train acc: 0.099000; val_acc: 0.098000
# (Epoch 18 / 20) train acc: 0.084000; val_acc: 0.078000
# (Iteration 9001 / 9800) loss: 2.301981
# (Epoch 19 / 20) train acc: 0.102000; val_acc: 0.119000
# (Epoch 20 / 20) train acc: 0.099000; val_acc: 0.078000
# **********************************
# hidden layer dim: 1000, lr: 1.0000, reg: 0.0000
# (Iteration 1 / 9800) loss: 2.302613
# (Epoch 0 / 20) train acc: 0.102000; val_acc: 0.087000
# (Epoch 1 / 20) train acc: 0.552000; val_acc: 0.529000
# (Epoch 2 / 20) train acc: 0.606000; val_acc: 0.538000
# (Iteration 1001 / 9800) loss: 1.136998
# (Epoch 3 / 20) train acc: 0.641000; val_acc: 0.552000
# (Epoch 4 / 20) train acc: 0.636000; val_acc: 0.544000
# (Iteration 2001 / 9800) loss: 1.253742
# (Epoch 5 / 20) train acc: 0.717000; val_acc: 0.507000
# (Epoch 6 / 20) train acc: 0.721000; val_acc: 0.537000
# (Iteration 3001 / 9800) loss: 0.783004
# (Epoch 7 / 20) train acc: 0.751000; val_acc: 0.535000
# (Epoch 8 / 20) train acc: 0.814000; val_acc: 0.549000
# (Iteration 4001 / 9800) loss: 0.632981
# (Epoch 9 / 20) train acc: 0.829000; val_acc: 0.534000
# (Epoch 10 / 20) train acc: 0.836000; val_acc: 0.542000
# (Iteration 5001 / 9800) loss: 0.834622
# (Epoch 11 / 20) train acc: 0.821000; val_acc: 0.533000
# (Epoch 12 / 20) train acc: 0.873000; val_acc: 0.545000
# (Iteration 6001 / 9800) loss: 0.300432
# (Epoch 13 / 20) train acc: 0.890000; val_acc: 0.534000
# (Epoch 14 / 20) train acc: 0.925000; val_acc: 0.565000
# (Iteration 7001 / 9800) loss: 0.185330
# (Epoch 15 / 20) train acc: 0.935000; val_acc: 0.561000
# (Epoch 16 / 20) train acc: 0.971000; val_acc: 0.547000
# (Iteration 8001 / 9800) loss: 0.094679
# (Epoch 17 / 20) train acc: 0.985000; val_acc: 0.565000
# (Epoch 18 / 20) train acc: 0.988000; val_acc: 0.556000
# (Iteration 9001 / 9800) loss: 0.040517
# (Epoch 19 / 20) train acc: 0.992000; val_acc: 0.552000
# (Epoch 20 / 20) train acc: 0.997000; val_acc: 0.562000
# **********************************
# hidden layer dim: 1000, lr: 1.0000, reg: 0.0100
# (Iteration 1 / 9800) loss: 2.303412
# (Epoch 0 / 20) train acc: 0.090000; val_acc: 0.107000
# (Epoch 1 / 20) train acc: 0.494000; val_acc: 0.480000
# (Epoch 2 / 20) train acc: 0.527000; val_acc: 0.477000
# (Iteration 1001 / 9800) loss: 1.742937
# (Epoch 3 / 20) train acc: 0.539000; val_acc: 0.506000
# (Epoch 4 / 20) train acc: 0.470000; val_acc: 0.460000
# (Iteration 2001 / 9800) loss: 1.736636
# (Epoch 5 / 20) train acc: 0.527000; val_acc: 0.518000
# (Epoch 6 / 20) train acc: 0.497000; val_acc: 0.479000
# (Iteration 3001 / 9800) loss: 1.538867
# (Epoch 7 / 20) train acc: 0.536000; val_acc: 0.526000
# (Epoch 8 / 20) train acc: 0.534000; val_acc: 0.496000
# (Iteration 4001 / 9800) loss: 1.555122
# (Epoch 9 / 20) train acc: 0.493000; val_acc: 0.524000
# (Epoch 10 / 20) train acc: 0.527000; val_acc: 0.527000
# (Iteration 5001 / 9800) loss: 1.628608
# (Epoch 11 / 20) train acc: 0.539000; val_acc: 0.515000
# (Epoch 12 / 20) train acc: 0.535000; val_acc: 0.501000
# (Iteration 6001 / 9800) loss: 1.617063
# (Epoch 13 / 20) train acc: 0.506000; val_acc: 0.484000
# (Epoch 14 / 20) train acc: 0.511000; val_acc: 0.488000
# (Iteration 7001 / 9800) loss: 1.465540
# (Epoch 15 / 20) train acc: 0.554000; val_acc: 0.502000
# (Epoch 16 / 20) train acc: 0.535000; val_acc: 0.517000
# (Iteration 8001 / 9800) loss: 1.653945
# (Epoch 17 / 20) train acc: 0.576000; val_acc: 0.534000
# (Epoch 18 / 20) train acc: 0.535000; val_acc: 0.529000
# (Iteration 9001 / 9800) loss: 1.562922
# (Epoch 19 / 20) train acc: 0.547000; val_acc: 0.536000
# (Epoch 20 / 20) train acc: 0.554000; val_acc: 0.529000
# **********************************
# hidden layer dim: 1000, lr: 1.0000, reg: 0.1000
# (Iteration 1 / 9800) loss: 2.310892
# (Epoch 0 / 20) train acc: 0.110000; val_acc: 0.119000
# (Epoch 1 / 20) train acc: 0.341000; val_acc: 0.345000
# (Epoch 2 / 20) train acc: 0.376000; val_acc: 0.350000
# (Iteration 1001 / 9800) loss: 2.106890
# (Epoch 3 / 20) train acc: 0.356000; val_acc: 0.339000
# (Epoch 4 / 20) train acc: 0.353000; val_acc: 0.328000
# (Iteration 2001 / 9800) loss: 2.121941
# (Epoch 5 / 20) train acc: 0.404000; val_acc: 0.383000
# (Epoch 6 / 20) train acc: 0.370000; val_acc: 0.371000
# (Iteration 3001 / 9800) loss: 1.971501
# (Epoch 7 / 20) train acc: 0.332000; val_acc: 0.338000
# (Epoch 8 / 20) train acc: 0.416000; val_acc: 0.365000
# (Iteration 4001 / 9800) loss: 2.050163
# (Epoch 9 / 20) train acc: 0.374000; val_acc: 0.342000
# (Epoch 10 / 20) train acc: 0.413000; val_acc: 0.355000
# (Iteration 5001 / 9800) loss: 2.074792
# (Epoch 11 / 20) train acc: 0.348000; val_acc: 0.337000
# (Epoch 12 / 20) train acc: 0.375000; val_acc: 0.360000
# (Iteration 6001 / 9800) loss: 2.027456
# (Epoch 13 / 20) train acc: 0.360000; val_acc: 0.337000
# (Epoch 14 / 20) train acc: 0.357000; val_acc: 0.331000
# (Iteration 7001 / 9800) loss: 1.987213
# (Epoch 15 / 20) train acc: 0.376000; val_acc: 0.373000
# (Epoch 16 / 20) train acc: 0.393000; val_acc: 0.371000
# (Iteration 8001 / 9800) loss: 1.868418
# (Epoch 17 / 20) train acc: 0.336000; val_acc: 0.349000
# (Epoch 18 / 20) train acc: 0.385000; val_acc: 0.375000
# (Iteration 9001 / 9800) loss: 1.942310
# (Epoch 19 / 20) train acc: 0.334000; val_acc: 0.364000
# (Epoch 20 / 20) train acc: 0.379000; val_acc: 0.389000
# **********************************
# hidden layer dim: 1000, lr: 1.0000, reg: 1.0000
# (Iteration 1 / 9800) loss: 2.384032
# (Epoch 0 / 20) train acc: 0.099000; val_acc: 0.105000
# (Epoch 1 / 20) train acc: 0.104000; val_acc: 0.112000
# (Epoch 2 / 20) train acc: 0.099000; val_acc: 0.087000
# (Iteration 1001 / 9800) loss: 2.308438
# (Epoch 3 / 20) train acc: 0.104000; val_acc: 0.078000
# (Epoch 4 / 20) train acc: 0.105000; val_acc: 0.107000
# (Iteration 2001 / 9800) loss: 2.296776
# (Epoch 5 / 20) train acc: 0.110000; val_acc: 0.087000
# (Epoch 6 / 20) train acc: 0.104000; val_acc: 0.098000
# (Iteration 3001 / 9800) loss: 2.293634
# (Epoch 7 / 20) train acc: 0.086000; val_acc: 0.119000
# (Epoch 8 / 20) train acc: 0.101000; val_acc: 0.098000
# (Iteration 4001 / 9800) loss: 2.299626
# (Epoch 9 / 20) train acc: 0.115000; val_acc: 0.087000
# (Epoch 10 / 20) train acc: 0.102000; val_acc: 0.102000
# (Iteration 5001 / 9800) loss: 2.305978
# (Epoch 11 / 20) train acc: 0.114000; val_acc: 0.079000
# (Epoch 12 / 20) train acc: 0.090000; val_acc: 0.119000
# (Iteration 6001 / 9800) loss: 2.298076
# (Epoch 13 / 20) train acc: 0.114000; val_acc: 0.113000
# (Epoch 14 / 20) train acc: 0.088000; val_acc: 0.105000
# (Iteration 7001 / 9800) loss: 2.316658
# (Epoch 15 / 20) train acc: 0.100000; val_acc: 0.119000
# (Epoch 16 / 20) train acc: 0.109000; val_acc: 0.119000
# (Iteration 8001 / 9800) loss: 2.296632
# (Epoch 17 / 20) train acc: 0.116000; val_acc: 0.119000
# (Epoch 18 / 20) train acc: 0.092000; val_acc: 0.078000
# (Iteration 9001 / 9800) loss: 2.303863
# (Epoch 19 / 20) train acc: 0.084000; val_acc: 0.102000
# (Epoch 20 / 20) train acc: 0.097000; val_acc: 0.087000
# best validation accuracy : 0.627000

# %%
# Run your best neural net classifier on the test set. You should be able
# to get more than 55% accuracy.
y_test_pred = np.argmax(best_net.loss(X_test_feats), axis=1)
test_acc = (y_test_pred == y_test).mean()
print(test_acc)
# Out:
# 0.612
